# %%
import pandas as pd
from googletrans import Translator

df = pd.read_csv('../markettwits.tsv', sep='\t')
df['Text'] = df['Text'].str.replace('\\n', '\n').str.replace('\\t', '\t')

bs = 100
i = 0
n = len(df)
translations = []

df
# Out:
#            ID                                               Text  \
# 0      315744               💥🇺🇸#INTC \nIntel назначил нового CEO
# 1      315743  ✴️#крипто #наблюдение \nSantiment отмечает рез...
# 2      315742         💥🇺🇸#TSLA = +7%  #NVDA = +6.5%  на закрытии
# 3      315741  ⚠️🇨🇦#дкп #канада #спикеры \nЦБ обсуждал паузу ...
# 4      315740  🛢🇺🇸#event #нефтегаз #сша \nРуководители нефтян...
# ...       ...                                                ...
# 43867  270925  🇺🇸#сша #отчетности\nкорпоративные отчетности С...
# 43868  270924  ✴️#крипто #разблокировки #календарь \nCryptora...
# 43869  270923  ✴️#крипто #разблокировки #календарь \nCryptora...
# 43870  270921  🗓#календарь\nКЛЮЧЕВЫЕ СОБЫТИЯ ЭТОЙ НЕДЕЛИ:\n\n...
# 43871  270920                                              💥🎄#нг
#
#                             Date
# 0      2025-03-12 20:30:54+00:00
# 1      2025-03-12 20:26:21+00:00
# 2      2025-03-12 20:20:07+00:00
# 3      2025-03-12 20:14:08+00:00
# ...

# %%
async with Translator() as translator:
    while i <= n:
        results = await translator.translate(list(df['Text'][i:i+bs]), src='ru')
        translations.extend(res.text for res in results)
        i += bs
# Out:
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File ~/Desktop/Invest-Predict main/prices-predictions/prices-predictions/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Desktop/Invest-Predict main/prices-predictions/prices-predictions/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/Desktop/Invest-Predict main/prices-predictions/prices-predictions/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
# ...

# %%
out_df = df.copy()[:len(translations)]
out_df['Text'] = translations
out_df['Text'] = out_df['Text'].str.replace('\n', '\\n').str.replace('\t', '\\t')
out_df
# Out:
#            ID                                               Text  \
# 0      315744               💥🇺🇸#Intc \nIntel appointed a new CEO
# 1      315743  ✴️ #Crypto #Observation \nSantiment notes a sh...
# 2      315742           💥🇺🇸 #tsla = +7% #NVDA = +6.5% in closing
# 3      315741  ⚠️🇨🇦 #DKP #Canada #Speaker \nThe Central Bank ...
# 4      315740  🛢🇺🇸 #Event #Oilogas #USA \nThe heads of the US...
# ...       ...                                                ...
# 12895  302614  ⚠️🇷🇺 #abrd #SPO\nDecember 18 - Abrau - Durso -...
# 12896  302613  💥🇷🇺#rual = +4% = Max from July on rally in alu...
# 12897  302612  💥✴️🇺🇸#sti\nTuzemun continues in Solidion Techn...
# 12898  302611  ✴️ #DOGE #COT #Crypto \nWhales have significan...
# 12899  302610  💥✴️ #btc #crypto #implementation #corporate \n...
#
#                             Date
# 0      2025-03-12 20:30:54+00:00
# 1      2025-03-12 20:26:21+00:00
# 2      2025-03-12 20:20:07+00:00
# 3      2025-03-12 20:14:08+00:00
# ...

# %%
out_df.to_csv('eng_markettwits.tsv', index=False, sep='\t')

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="ProsusAI/finbert")

# %%
import pandas as pd
from googletrans import Translator


translator = Translator()

df = pd.read_csv('../markettwits.tsv', sep='\t')

# df['TranslatedText'] = df['Text'].apply(lambda x: translator.translate(x, src='ru', dest='en').text)
#df['TranslatedText'] = df.apply(lambda row: translator.translate(row['Text'], src='ru', dest='en').text, axis=1)
d = pd.DataFrame({'Spanish':['piso','cama']})
d['English'] = d['Spanish'].apply(translator.translate, src='es', dest='en').apply(getattr, args=('text',))

df.to_csv('translated_output.tsv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 12
#       9 # df['TranslatedText'] = df['Text'].apply(lambda x: translator.translate(x, src='ru', dest='en').text)
#      10 #df['TranslatedText'] = df.apply(lambda row: translator.translate(row['Text'], src='ru', dest='en').text, axis=1)
#      11 d = pd.DataFrame({'Spanish':['piso','cama']})
# ---> 12 d['English'] = d['Spanish'].apply(translator.translate, src='es', dest='en').apply(getattr, args=('text',))
#      14 df.to_csv('translated_output.tsv', index=False)
#
# File ~/Desktop/Invest-Predict main/prices-predictions/prices-predictions/.venv/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
# ...

# %%
import pandas as pd
from googletrans import Translator

df = pd.read_csv('../markettwits.tsv', sep='\t')
df = df[df['Date'] > '2025-02-01 00:00:01+00:00']

async def translate_list(list):
    results = []
    async with Translator() as translator:
        for s in list:
            result = await translator.translate(str(s).replace('\\n', '\n').replace('\\t', '\t'), src='ru', dest='en')
            results.append(result.text.replace('\n', '\\n').replace('\t', '\\t'))
    return results

translated_texts = await translate_list(df['Text'].to_list())
list_df = pd.DataFrame({'EnglishText' : translated_texts})
merged_df = pd.concat([df, list_df], axis=1)
merged_df.to_csv('translated_output.tsv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File ~/Desktop/Invest-Predict main/prices-predictions/prices-predictions/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Desktop/Invest-Predict main/prices-predictions/prices-predictions/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/Desktop/Invest-Predict main/prices-predictions/prices-predictions/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
# ...

# %%
import asyncio

df = pd.read_csv('../markettwits.tsv', sep='\t')

async with Translator() as translator:
    translations = await translator.translate(df['Text'].to_list().replace('\\n', '\n').replace('\\t', '\t'), src='ru', dest='en')
    for translation in translations:
        print(translation.text)

asyncio.run(translate_bulk())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py:789: RuntimeWarning: coroutine 'Translator.translate' was never awaited
#   def call_soon(self, callback, *args, context=None):
# ...
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[20], line 6
#       3 df = pd.read_csv('../markettwits.tsv', sep='\t')
#       5 async with Translator() as translator:
# ----> 6     translations = await translator.translate(df['Text'].to_list(), src='ru', dest='en')
#       7     for translation in translations:
#       8         print(translation.text)
#
# File ~/Desktop/Invest-Predict main/prices-predictions/prices-predictions/.venv/lib/python3.12/site-packages/googletrans/client.py:282, in Translator.translate(self, text, dest, src, **kwargs)
#     279             return await self.translate(item, dest=dest, src=src, **kwargs)
# ...
