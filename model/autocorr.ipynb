# %% [markdown]
# #### Анализ временного ряда на автокорреляцию и построению авторегрессионных моделей. Все по ценам закрытия.

# %%
# %load_ext IPython.extensions.autoreload
# %autoreload 2
import datetime as dt
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt
import numpy as np

from data import FinData
# Out:
# The IPython.extensions.autoreload extension is already loaded. To reload it, use:
#   %reload_ext IPython.extensions.autoreload

# %%
data = FinData("../datasets/T_yandex_10min.csv")
data.insert_stat_close_price()
data.check_stationarity(columns=["stat_close_price"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 3
#       1 data = FinData("../datasets/T_yandex_10min.csv")
#       2 data.insert_stat_close_price()
# ----> 3 data.check_stationarity(columns=["stat_close_price"])
#
# File c:\Users\Валерия\OneDrive\Документы\GitHub\prices-predictions\model\data.py:176, in FinData.check_stationarity(self, columns)
#     174 # результаты тестов
#     175 pp_result = PhillipsPerron(series)
# --> 176 adf_result = adfuller(series, autolag='AIC')
#     177 za_result = zivot_andrews(series, trim=0.15)
#     179 # проверка p-value для каждого теста
#
# File c:\Users\Валерия\OneDrive\Документы\GitHub\prices-predictions\myenv\Lib\site-packages\statsmodels\tsa\stattools.py:326, in adfuller(x, maxlag, regression, autolag, store, regresults)
#     320 # 1 for level
#     321 # search for lag length with smallest information criteria
#     322 # Note: use the same number of observations to have comparable IC
#     323 # aic and bic: smaller is better
#     325 if not regresults:
# --> 326     icbest, bestlag = _autolag(
#     327         OLS, xdshort, fullRHS, startlag, maxlag, autolag
#     328     )
#     329 else:
#     330     icbest, bestlag, alres = _autolag(
#     331         OLS,
#     332         xdshort,
#    (...)
#     337         regresults=regresults,
#     338     )
#
# File c:\Users\Валерия\OneDrive\Документы\GitHub\prices-predictions\myenv\Lib\site-packages\statsmodels\tsa\stattools.py:133, in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#     131 for lag in range(startlag, startlag + maxlag + 1):
#     132     mod_instance = mod(endog, exog[:, :lag], *modargs)
# --> 133     results[lag] = mod_instance.fit()
#     135 if method == "aic":
#     136     icbest, bestlag = min((v.aic, k) for k, v in results.items())
#
# File c:\Users\Валерия\OneDrive\Документы\GitHub\prices-predictions\myenv\Lib\site-packages\statsmodels\regression\linear_model.py:333, in RegressionModel.fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     328 if method == "pinv":
#     329     if not (hasattr(self, 'pinv_wexog') and
#     330             hasattr(self, 'normalized_cov_params') and
#     331             hasattr(self, 'rank')):
# --> 333         self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     334         self.normalized_cov_params = np.dot(
#     335             self.pinv_wexog, np.transpose(self.pinv_wexog))
#     337         # Cache these singular values for use later.
#
# File c:\Users\Валерия\OneDrive\Документы\GitHub\prices-predictions\myenv\Lib\site-packages\statsmodels\tools\tools.py:264, in pinv_extended(x, rcond)
#     262 x = np.asarray(x)
#     263 x = x.conjugate()
# --> 264 u, s, vt = np.linalg.svd(x, False)
#     265 s_orig = np.copy(s)
#     266 m = u.shape[0]
#
# File c:\Users\Валерия\OneDrive\Документы\GitHub\prices-predictions\myenv\Lib\site-packages\numpy\linalg\linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#    1678         gufunc = _umath_linalg.svd_n_s
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1682 u = u.astype(result_t, copy=False)
#    1683 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %% [markdown]
# 1.1) Функция на подсчет автокорреляций для подбора лагов

# %%
def calculate_autocorrelation(df, column, lags):
    """
    Вычисляет коэффициенты автокорреляции для заданной колонки датафрейма на указанных лагах.

    Параметры:
        df (pd.DataFrame): Входной датафрейм.
        column (str): Название колонки для анализа.
        lags (list): Список лагов, для которых нужно вычислить автокорреляцию.

    Выводит коэффициенты автокорреляции для каждого лага.
    """
    if column not in df.columns:
        raise ValueError(f"Колонка '{column}' отсутствует в датафрейме.")

    print(f"Коэффициенты автокорреляции для колонки '{column}':")
    for lag in lags:
        autocorr = df[column].autocorr(lag=lag)
        print(f"Лаг {lag}: {autocorr:.4f}")

# %%
lags = [2, 3, 4, 5, 6, 10, 20, 50, 1000, 2000]
calculate_autocorrelation(data.df, column="close", lags=lags)
# Out:
# Коэффициенты автокорреляции для колонки 'close':
# Лаг 2: 0.9999
# Лаг 3: 0.9999
# Лаг 4: 0.9999
# Лаг 5: 0.9999
# Лаг 6: 0.9998
# Лаг 10: 0.9997
# Лаг 20: 0.9995
# Лаг 50: 0.9987
# Лаг 1000: 0.9722
# Лаг 2000: 0.9411

# %% [markdown]
# Обрежем датасет до 2 месяцев и снова посмотрим значения коэффициентов автокорреляции

# %%
start_date = dt.datetime(2023, 2, 1)
end_date = dt.datetime(2023, 4, 1)

data.restrict_time_down(start_date)
data.restrict_time_up(end_date)

lags = [2, 3, 4, 5, 6, 10, 20, 50, 100, 500, 1000, 2000]
calculate_autocorrelation(data.df, column="close", lags=lags)
# Out:
# Коэффициенты автокорреляции для колонки 'close':
# Лаг 2: 0.9885
# Лаг 3: 0.9852
# Лаг 4: 0.9818
# Лаг 5: 0.9784
# Лаг 6: 0.9750
# Лаг 10: 0.9625
# Лаг 20: 0.9350
# Лаг 50: 0.8879
# Лаг 100: 0.8063
# Лаг 500: 0.4104
# Лаг 1000: -0.3730
# Лаг 2000: -0.0010

# %% [markdown]
# 1.2) Статистический критерий Льюнга-Бокса на значимость автокорреляции

# %% [markdown]
# Если значение p-value критерия не превосходит $0.05$ (или другого заранее фиксированного порога значимости), то автокорреляция с лагом $x$ значима.

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

# %%
def ljung_box_test(df, column, lags):
    """
    Выполняет статистический тест Льюнга-Бокса на значимость автокорреляции.

    Параметры:
        df (pd.DataFrame): Входной датафрейм.
        column (str): Название колонки для анализа.
        lags (int) | : Максимальное количество лагов для теста.

    Выводит результаты теста для каждого лага.
    """
    lb_test = acorr_ljungbox(df[column].dropna(), lags=1000, return_df=True)
    
    print(f"Результаты теста Льюнга-Бокса для колонки '{column}':")
    for lag, p_value in zip(lb_test.index, lb_test['lb_pvalue']):
        res = "значима" if p_value < 0.05 else "незначима"
        print(f"Лаг {lag}: p-значение = {p_value:.4f} ({res})")

# %%
ljung_box_test(data.df, column="close", lags=lags)
# Out:
# Результаты теста Льюнга-Бокса для колонки 'close':
# Лаг 1: p-значение = 0.0000 (значима)
# Лаг 2: p-значение = 0.0000 (значима)
# Лаг 3: p-значение = 0.0000 (значима)
# Лаг 4: p-значение = 0.0000 (значима)
# Лаг 5: p-значение = 0.0000 (значима)
# Лаг 6: p-значение = 0.0000 (значима)
# Лаг 7: p-значение = 0.0000 (значима)
# Лаг 8: p-значение = 0.0000 (значима)
# Лаг 9: p-значение = 0.0000 (значима)
# Лаг 10: p-значение = 0.0000 (значима)
# Лаг 11: p-значение = 0.0000 (значима)
# Лаг 12: p-значение = 0.0000 (значима)
# Лаг 13: p-значение = 0.0000 (значима)
# Лаг 14: p-значение = 0.0000 (значима)
# Лаг 15: p-значение = 0.0000 (значима)
# Лаг 16: p-значение = 0.0000 (значима)
# Лаг 17: p-значение = 0.0000 (значима)
# Лаг 18: p-значение = 0.0000 (значима)
# Лаг 19: p-значение = 0.0000 (значима)
# Лаг 20: p-значение = 0.0000 (значима)
# Лаг 21: p-значение = 0.0000 (значима)
# Лаг 22: p-значение = 0.0000 (значима)
# Лаг 23: p-значение = 0.0000 (значима)
# Лаг 24: p-значение = 0.0000 (значима)
# Лаг 25: p-значение = 0.0000 (значима)
# Лаг 26: p-значение = 0.0000 (значима)
# Лаг 27: p-значение = 0.0000 (значима)
# Лаг 28: p-значение = 0.0000 (значима)
# Лаг 29: p-значение = 0.0000 (значима)
# Лаг 30: p-значение = 0.0000 (значима)
# Лаг 31: p-значение = 0.0000 (значима)
# Лаг 32: p-значение = 0.0000 (значима)
# Лаг 33: p-значение = 0.0000 (значима)
# Лаг 34: p-значение = 0.0000 (значима)
# Лаг 35: p-значение = 0.0000 (значима)
# Лаг 36: p-значение = 0.0000 (значима)
# Лаг 37: p-значение = 0.0000 (значима)
# Лаг 38: p-значение = 0.0000 (значима)
# Лаг 39: p-значение = 0.0000 (значима)
# Лаг 40: p-значение = 0.0000 (значима)
# Лаг 41: p-значение = 0.0000 (значима)
# Лаг 42: p-значение = 0.0000 (значима)
# Лаг 43: p-значение = 0.0000 (значима)
# Лаг 44: p-значение = 0.0000 (значима)
# Лаг 45: p-значение = 0.0000 (значима)
# Лаг 46: p-значение = 0.0000 (значима)
# Лаг 47: p-значение = 0.0000 (значима)
# Лаг 48: p-значение = 0.0000 (значима)
# Лаг 49: p-значение = 0.0000 (значима)
# Лаг 50: p-значение = 0.0000 (значима)
# Лаг 51: p-значение = 0.0000 (значима)
# Лаг 52: p-значение = 0.0000 (значима)
# Лаг 53: p-значение = 0.0000 (значима)
# Лаг 54: p-значение = 0.0000 (значима)
# Лаг 55: p-значение = 0.0000 (значима)
# Лаг 56: p-значение = 0.0000 (значима)
# Лаг 57: p-значение = 0.0000 (значима)
# Лаг 58: p-значение = 0.0000 (значима)
# Лаг 59: p-значение = 0.0000 (значима)
# Лаг 60: p-значение = 0.0000 (значима)
# Лаг 61: p-значение = 0.0000 (значима)
# Лаг 62: p-значение = 0.0000 (значима)
# Лаг 63: p-значение = 0.0000 (значима)
# Лаг 64: p-значение = 0.0000 (значима)
# Лаг 65: p-значение = 0.0000 (значима)
# Лаг 66: p-значение = 0.0000 (значима)
# Лаг 67: p-значение = 0.0000 (значима)
# Лаг 68: p-значение = 0.0000 (значима)
# Лаг 69: p-значение = 0.0000 (значима)
# Лаг 70: p-значение = 0.0000 (значима)
# Лаг 71: p-значение = 0.0000 (значима)
# Лаг 72: p-значение = 0.0000 (значима)
# Лаг 73: p-значение = 0.0000 (значима)
# Лаг 74: p-значение = 0.0000 (значима)
# Лаг 75: p-значение = 0.0000 (значима)
# Лаг 76: p-значение = 0.0000 (значима)
# Лаг 77: p-значение = 0.0000 (значима)
# Лаг 78: p-значение = 0.0000 (значима)
# Лаг 79: p-значение = 0.0000 (значима)
# Лаг 80: p-значение = 0.0000 (значима)
# Лаг 81: p-значение = 0.0000 (значима)
# Лаг 82: p-значение = 0.0000 (значима)
# Лаг 83: p-значение = 0.0000 (значима)
# Лаг 84: p-значение = 0.0000 (значима)
# Лаг 85: p-значение = 0.0000 (значима)
# Лаг 86: p-значение = 0.0000 (значима)
# Лаг 87: p-значение = 0.0000 (значима)
# Лаг 88: p-значение = 0.0000 (значима)
# Лаг 89: p-значение = 0.0000 (значима)
# Лаг 90: p-значение = 0.0000 (значима)
# Лаг 91: p-значение = 0.0000 (значима)
# Лаг 92: p-значение = 0.0000 (значима)
# Лаг 93: p-значение = 0.0000 (значима)
# Лаг 94: p-значение = 0.0000 (значима)
# Лаг 95: p-значение = 0.0000 (значима)
# Лаг 96: p-значение = 0.0000 (значима)
# Лаг 97: p-значение = 0.0000 (значима)
# Лаг 98: p-значение = 0.0000 (значима)
# Лаг 99: p-значение = 0.0000 (значима)
# Лаг 100: p-значение = 0.0000 (значима)
# Лаг 101: p-значение = 0.0000 (значима)
# Лаг 102: p-значение = 0.0000 (значима)
# Лаг 103: p-значение = 0.0000 (значима)
# Лаг 104: p-значение = 0.0000 (значима)
# Лаг 105: p-значение = 0.0000 (значима)
# Лаг 106: p-значение = 0.0000 (значима)
# Лаг 107: p-значение = 0.0000 (значима)
# Лаг 108: p-значение = 0.0000 (значима)
# Лаг 109: p-значение = 0.0000 (значима)
# Лаг 110: p-значение = 0.0000 (значима)
# Лаг 111: p-значение = 0.0000 (значима)
# Лаг 112: p-значение = 0.0000 (значима)
# Лаг 113: p-значение = 0.0000 (значима)
# Лаг 114: p-значение = 0.0000 (значима)
# Лаг 115: p-значение = 0.0000 (значима)
# Лаг 116: p-значение = 0.0000 (значима)
# Лаг 117: p-значение = 0.0000 (значима)
# Лаг 118: p-значение = 0.0000 (значима)
# Лаг 119: p-значение = 0.0000 (значима)
# Лаг 120: p-значение = 0.0000 (значима)
# Лаг 121: p-значение = 0.0000 (значима)
# Лаг 122: p-значение = 0.0000 (значима)
# Лаг 123: p-значение = 0.0000 (значима)
# Лаг 124: p-значение = 0.0000 (значима)
# Лаг 125: p-значение = 0.0000 (значима)
# Лаг 126: p-значение = 0.0000 (значима)
# Лаг 127: p-значение = 0.0000 (значима)
# Лаг 128: p-значение = 0.0000 (значима)
# Лаг 129: p-значение = 0.0000 (значима)
# Лаг 130: p-значение = 0.0000 (значима)
# Лаг 131: p-значение = 0.0000 (значима)
# Лаг 132: p-значение = 0.0000 (значима)
# Лаг 133: p-значение = 0.0000 (значима)
# Лаг 134: p-значение = 0.0000 (значима)
# Лаг 135: p-значение = 0.0000 (значима)
# Лаг 136: p-значение = 0.0000 (значима)
# Лаг 137: p-значение = 0.0000 (значима)
# Лаг 138: p-значение = 0.0000 (значима)
# Лаг 139: p-значение = 0.0000 (значима)
# Лаг 140: p-значение = 0.0000 (значима)
# Лаг 141: p-значение = 0.0000 (значима)
# Лаг 142: p-значение = 0.0000 (значима)
# Лаг 143: p-значение = 0.0000 (значима)
# Лаг 144: p-значение = 0.0000 (значима)
# Лаг 145: p-значение = 0.0000 (значима)
# Лаг 146: p-значение = 0.0000 (значима)
# Лаг 147: p-значение = 0.0000 (значима)
# Лаг 148: p-значение = 0.0000 (значима)
# Лаг 149: p-значение = 0.0000 (значима)
# Лаг 150: p-значение = 0.0000 (значима)
# Лаг 151: p-значение = 0.0000 (значима)
# Лаг 152: p-значение = 0.0000 (значима)
# Лаг 153: p-значение = 0.0000 (значима)
# Лаг 154: p-значение = 0.0000 (значима)
# Лаг 155: p-значение = 0.0000 (значима)
# Лаг 156: p-значение = 0.0000 (значима)
# Лаг 157: p-значение = 0.0000 (значима)
# Лаг 158: p-значение = 0.0000 (значима)
# Лаг 159: p-значение = 0.0000 (значима)
# Лаг 160: p-значение = 0.0000 (значима)
# Лаг 161: p-значение = 0.0000 (значима)
# Лаг 162: p-значение = 0.0000 (значима)
# Лаг 163: p-значение = 0.0000 (значима)
# Лаг 164: p-значение = 0.0000 (значима)
# Лаг 165: p-значение = 0.0000 (значима)
# Лаг 166: p-значение = 0.0000 (значима)
# Лаг 167: p-значение = 0.0000 (значима)
# Лаг 168: p-значение = 0.0000 (значима)
# Лаг 169: p-значение = 0.0000 (значима)
# Лаг 170: p-значение = 0.0000 (значима)
# Лаг 171: p-значение = 0.0000 (значима)
# Лаг 172: p-значение = 0.0000 (значима)
# Лаг 173: p-значение = 0.0000 (значима)
# Лаг 174: p-значение = 0.0000 (значима)
# Лаг 175: p-значение = 0.0000 (значима)
# Лаг 176: p-значение = 0.0000 (значима)
# Лаг 177: p-значение = 0.0000 (значима)
# Лаг 178: p-значение = 0.0000 (значима)
# Лаг 179: p-значение = 0.0000 (значима)
# Лаг 180: p-значение = 0.0000 (значима)
# Лаг 181: p-значение = 0.0000 (значима)
# Лаг 182: p-значение = 0.0000 (значима)
# Лаг 183: p-значение = 0.0000 (значима)
# Лаг 184: p-значение = 0.0000 (значима)
# Лаг 185: p-значение = 0.0000 (значима)
# Лаг 186: p-значение = 0.0000 (значима)
# Лаг 187: p-значение = 0.0000 (значима)
# Лаг 188: p-значение = 0.0000 (значима)
# Лаг 189: p-значение = 0.0000 (значима)
# Лаг 190: p-значение = 0.0000 (значима)
# Лаг 191: p-значение = 0.0000 (значима)
# Лаг 192: p-значение = 0.0000 (значима)
# Лаг 193: p-значение = 0.0000 (значима)
# Лаг 194: p-значение = 0.0000 (значима)
# Лаг 195: p-значение = 0.0000 (значима)
# Лаг 196: p-значение = 0.0000 (значима)
# Лаг 197: p-значение = 0.0000 (значима)
# Лаг 198: p-значение = 0.0000 (значима)
# Лаг 199: p-значение = 0.0000 (значима)
# Лаг 200: p-значение = 0.0000 (значима)
# Лаг 201: p-значение = 0.0000 (значима)
# Лаг 202: p-значение = 0.0000 (значима)
# Лаг 203: p-значение = 0.0000 (значима)
# Лаг 204: p-значение = 0.0000 (значима)
# Лаг 205: p-значение = 0.0000 (значима)
# Лаг 206: p-значение = 0.0000 (значима)
# Лаг 207: p-значение = 0.0000 (значима)
# Лаг 208: p-значение = 0.0000 (значима)
# Лаг 209: p-значение = 0.0000 (значима)
# Лаг 210: p-значение = 0.0000 (значима)
# Лаг 211: p-значение = 0.0000 (значима)
# Лаг 212: p-значение = 0.0000 (значима)
# Лаг 213: p-значение = 0.0000 (значима)
# Лаг 214: p-значение = 0.0000 (значима)
# Лаг 215: p-значение = 0.0000 (значима)
# Лаг 216: p-значение = 0.0000 (значима)
# Лаг 217: p-значение = 0.0000 (значима)
# Лаг 218: p-значение = 0.0000 (значима)
# Лаг 219: p-значение = 0.0000 (значима)
# Лаг 220: p-значение = 0.0000 (значима)
# Лаг 221: p-значение = 0.0000 (значима)
# Лаг 222: p-значение = 0.0000 (значима)
# Лаг 223: p-значение = 0.0000 (значима)
# Лаг 224: p-значение = 0.0000 (значима)
# Лаг 225: p-значение = 0.0000 (значима)
# Лаг 226: p-значение = 0.0000 (значима)
# Лаг 227: p-значение = 0.0000 (значима)
# Лаг 228: p-значение = 0.0000 (значима)
# Лаг 229: p-значение = 0.0000 (значима)
# Лаг 230: p-значение = 0.0000 (значима)
# Лаг 231: p-значение = 0.0000 (значима)
# Лаг 232: p-значение = 0.0000 (значима)
# Лаг 233: p-значение = 0.0000 (значима)
# Лаг 234: p-значение = 0.0000 (значима)
# Лаг 235: p-значение = 0.0000 (значима)
# Лаг 236: p-значение = 0.0000 (значима)
# Лаг 237: p-значение = 0.0000 (значима)
# Лаг 238: p-значение = 0.0000 (значима)
# Лаг 239: p-значение = 0.0000 (значима)
# Лаг 240: p-значение = 0.0000 (значима)
# Лаг 241: p-значение = 0.0000 (значима)
# Лаг 242: p-значение = 0.0000 (значима)
# Лаг 243: p-значение = 0.0000 (значима)
# Лаг 244: p-значение = 0.0000 (значима)
# Лаг 245: p-значение = 0.0000 (значима)
# Лаг 246: p-значение = 0.0000 (значима)
# Лаг 247: p-значение = 0.0000 (значима)
# Лаг 248: p-значение = 0.0000 (значима)
# Лаг 249: p-значение = 0.0000 (значима)
# Лаг 250: p-значение = 0.0000 (значима)
# Лаг 251: p-значение = 0.0000 (значима)
# Лаг 252: p-значение = 0.0000 (значима)
# Лаг 253: p-значение = 0.0000 (значима)
# Лаг 254: p-значение = 0.0000 (значима)
# Лаг 255: p-значение = 0.0000 (значима)
# Лаг 256: p-значение = 0.0000 (значима)
# Лаг 257: p-значение = 0.0000 (значима)
# Лаг 258: p-значение = 0.0000 (значима)
# Лаг 259: p-значение = 0.0000 (значима)
# Лаг 260: p-значение = 0.0000 (значима)
# Лаг 261: p-значение = 0.0000 (значима)
# Лаг 262: p-значение = 0.0000 (значима)
# Лаг 263: p-значение = 0.0000 (значима)
# Лаг 264: p-значение = 0.0000 (значима)
# Лаг 265: p-значение = 0.0000 (значима)
# Лаг 266: p-значение = 0.0000 (значима)
# Лаг 267: p-значение = 0.0000 (значима)
# Лаг 268: p-значение = 0.0000 (значима)
# Лаг 269: p-значение = 0.0000 (значима)
# Лаг 270: p-значение = 0.0000 (значима)
# Лаг 271: p-значение = 0.0000 (значима)
# Лаг 272: p-значение = 0.0000 (значима)
# Лаг 273: p-значение = 0.0000 (значима)
# Лаг 274: p-значение = 0.0000 (значима)
# Лаг 275: p-значение = 0.0000 (значима)
# Лаг 276: p-значение = 0.0000 (значима)
# Лаг 277: p-значение = 0.0000 (значима)
# Лаг 278: p-значение = 0.0000 (значима)
# Лаг 279: p-значение = 0.0000 (значима)
# Лаг 280: p-значение = 0.0000 (значима)
# Лаг 281: p-значение = 0.0000 (значима)
# Лаг 282: p-значение = 0.0000 (значима)
# Лаг 283: p-значение = 0.0000 (значима)
# Лаг 284: p-значение = 0.0000 (значима)
# Лаг 285: p-значение = 0.0000 (значима)
# Лаг 286: p-значение = 0.0000 (значима)
# Лаг 287: p-значение = 0.0000 (значима)
# Лаг 288: p-значение = 0.0000 (значима)
# Лаг 289: p-значение = 0.0000 (значима)
# Лаг 290: p-значение = 0.0000 (значима)
# Лаг 291: p-значение = 0.0000 (значима)
# Лаг 292: p-значение = 0.0000 (значима)
# Лаг 293: p-значение = 0.0000 (значима)
# Лаг 294: p-значение = 0.0000 (значима)
# Лаг 295: p-значение = 0.0000 (значима)
# Лаг 296: p-значение = 0.0000 (значима)
# Лаг 297: p-значение = 0.0000 (значима)
# Лаг 298: p-значение = 0.0000 (значима)
# Лаг 299: p-значение = 0.0000 (значима)
# Лаг 300: p-значение = 0.0000 (значима)
# Лаг 301: p-значение = 0.0000 (значима)
# Лаг 302: p-значение = 0.0000 (значима)
# Лаг 303: p-значение = 0.0000 (значима)
# Лаг 304: p-значение = 0.0000 (значима)
# Лаг 305: p-значение = 0.0000 (значима)
# Лаг 306: p-значение = 0.0000 (значима)
# Лаг 307: p-значение = 0.0000 (значима)
# Лаг 308: p-значение = 0.0000 (значима)
# Лаг 309: p-значение = 0.0000 (значима)
# Лаг 310: p-значение = 0.0000 (значима)
# Лаг 311: p-значение = 0.0000 (значима)
# Лаг 312: p-значение = 0.0000 (значима)
# Лаг 313: p-значение = 0.0000 (значима)
# Лаг 314: p-значение = 0.0000 (значима)
# Лаг 315: p-значение = 0.0000 (значима)
# Лаг 316: p-значение = 0.0000 (значима)
# Лаг 317: p-значение = 0.0000 (значима)
# Лаг 318: p-значение = 0.0000 (значима)
# Лаг 319: p-значение = 0.0000 (значима)
# Лаг 320: p-значение = 0.0000 (значима)
# Лаг 321: p-значение = 0.0000 (значима)
# Лаг 322: p-значение = 0.0000 (значима)
# Лаг 323: p-значение = 0.0000 (значима)
# Лаг 324: p-значение = 0.0000 (значима)
# Лаг 325: p-значение = 0.0000 (значима)
# Лаг 326: p-значение = 0.0000 (значима)
# Лаг 327: p-значение = 0.0000 (значима)
# Лаг 328: p-значение = 0.0000 (значима)
# Лаг 329: p-значение = 0.0000 (значима)
# Лаг 330: p-значение = 0.0000 (значима)
# Лаг 331: p-значение = 0.0000 (значима)
# Лаг 332: p-значение = 0.0000 (значима)
# Лаг 333: p-значение = 0.0000 (значима)
# Лаг 334: p-значение = 0.0000 (значима)
# Лаг 335: p-значение = 0.0000 (значима)
# Лаг 336: p-значение = 0.0000 (значима)
# Лаг 337: p-значение = 0.0000 (значима)
# Лаг 338: p-значение = 0.0000 (значима)
# Лаг 339: p-значение = 0.0000 (значима)
# Лаг 340: p-значение = 0.0000 (значима)
# Лаг 341: p-значение = 0.0000 (значима)
# Лаг 342: p-значение = 0.0000 (значима)
# Лаг 343: p-значение = 0.0000 (значима)
# Лаг 344: p-значение = 0.0000 (значима)
# Лаг 345: p-значение = 0.0000 (значима)
# Лаг 346: p-значение = 0.0000 (значима)
# Лаг 347: p-значение = 0.0000 (значима)
# Лаг 348: p-значение = 0.0000 (значима)
# Лаг 349: p-значение = 0.0000 (значима)
# Лаг 350: p-значение = 0.0000 (значима)
# Лаг 351: p-значение = 0.0000 (значима)
# Лаг 352: p-значение = 0.0000 (значима)
# Лаг 353: p-значение = 0.0000 (значима)
# Лаг 354: p-значение = 0.0000 (значима)
# Лаг 355: p-значение = 0.0000 (значима)
# Лаг 356: p-значение = 0.0000 (значима)
# Лаг 357: p-значение = 0.0000 (значима)
# Лаг 358: p-значение = 0.0000 (значима)
# Лаг 359: p-значение = 0.0000 (значима)
# Лаг 360: p-значение = 0.0000 (значима)
# Лаг 361: p-значение = 0.0000 (значима)
# Лаг 362: p-значение = 0.0000 (значима)
# Лаг 363: p-значение = 0.0000 (значима)
# Лаг 364: p-значение = 0.0000 (значима)
# Лаг 365: p-значение = 0.0000 (значима)
# Лаг 366: p-значение = 0.0000 (значима)
# Лаг 367: p-значение = 0.0000 (значима)
# Лаг 368: p-значение = 0.0000 (значима)
# Лаг 369: p-значение = 0.0000 (значима)
# Лаг 370: p-значение = 0.0000 (значима)
# Лаг 371: p-значение = 0.0000 (значима)
# Лаг 372: p-значение = 0.0000 (значима)
# Лаг 373: p-значение = 0.0000 (значима)
# Лаг 374: p-значение = 0.0000 (значима)
# Лаг 375: p-значение = 0.0000 (значима)
# Лаг 376: p-значение = 0.0000 (значима)
# Лаг 377: p-значение = 0.0000 (значима)
# Лаг 378: p-значение = 0.0000 (значима)
# Лаг 379: p-значение = 0.0000 (значима)
# Лаг 380: p-значение = 0.0000 (значима)
# Лаг 381: p-значение = 0.0000 (значима)
# Лаг 382: p-значение = 0.0000 (значима)
# Лаг 383: p-значение = 0.0000 (значима)
# Лаг 384: p-значение = 0.0000 (значима)
# Лаг 385: p-значение = 0.0000 (значима)
# Лаг 386: p-значение = 0.0000 (значима)
# Лаг 387: p-значение = 0.0000 (значима)
# Лаг 388: p-значение = 0.0000 (значима)
# Лаг 389: p-значение = 0.0000 (значима)
# Лаг 390: p-значение = 0.0000 (значима)
# Лаг 391: p-значение = 0.0000 (значима)
# Лаг 392: p-значение = 0.0000 (значима)
# Лаг 393: p-значение = 0.0000 (значима)
# Лаг 394: p-значение = 0.0000 (значима)
# Лаг 395: p-значение = 0.0000 (значима)
# Лаг 396: p-значение = 0.0000 (значима)
# Лаг 397: p-значение = 0.0000 (значима)
# Лаг 398: p-значение = 0.0000 (значима)
# Лаг 399: p-значение = 0.0000 (значима)
# Лаг 400: p-значение = 0.0000 (значима)
# Лаг 401: p-значение = 0.0000 (значима)
# Лаг 402: p-значение = 0.0000 (значима)
# Лаг 403: p-значение = 0.0000 (значима)
# Лаг 404: p-значение = 0.0000 (значима)
# Лаг 405: p-значение = 0.0000 (значима)
# Лаг 406: p-значение = 0.0000 (значима)
# Лаг 407: p-значение = 0.0000 (значима)
# Лаг 408: p-значение = 0.0000 (значима)
# Лаг 409: p-значение = 0.0000 (значима)
# Лаг 410: p-значение = 0.0000 (значима)
# Лаг 411: p-значение = 0.0000 (значима)
# Лаг 412: p-значение = 0.0000 (значима)
# Лаг 413: p-значение = 0.0000 (значима)
# Лаг 414: p-значение = 0.0000 (значима)
# Лаг 415: p-значение = 0.0000 (значима)
# Лаг 416: p-значение = 0.0000 (значима)
# Лаг 417: p-значение = 0.0000 (значима)
# Лаг 418: p-значение = 0.0000 (значима)
# Лаг 419: p-значение = 0.0000 (значима)
# Лаг 420: p-значение = 0.0000 (значима)
# Лаг 421: p-значение = 0.0000 (значима)
# Лаг 422: p-значение = 0.0000 (значима)
# Лаг 423: p-значение = 0.0000 (значима)
# Лаг 424: p-значение = 0.0000 (значима)
# Лаг 425: p-значение = 0.0000 (значима)
# Лаг 426: p-значение = 0.0000 (значима)
# Лаг 427: p-значение = 0.0000 (значима)
# Лаг 428: p-значение = 0.0000 (значима)
# Лаг 429: p-значение = 0.0000 (значима)
# Лаг 430: p-значение = 0.0000 (значима)
# Лаг 431: p-значение = 0.0000 (значима)
# Лаг 432: p-значение = 0.0000 (значима)
# Лаг 433: p-значение = 0.0000 (значима)
# Лаг 434: p-значение = 0.0000 (значима)
# Лаг 435: p-значение = 0.0000 (значима)
# Лаг 436: p-значение = 0.0000 (значима)
# Лаг 437: p-значение = 0.0000 (значима)
# Лаг 438: p-значение = 0.0000 (значима)
# Лаг 439: p-значение = 0.0000 (значима)
# Лаг 440: p-значение = 0.0000 (значима)
# Лаг 441: p-значение = 0.0000 (значима)
# Лаг 442: p-значение = 0.0000 (значима)
# Лаг 443: p-значение = 0.0000 (значима)
# Лаг 444: p-значение = 0.0000 (значима)
# Лаг 445: p-значение = 0.0000 (значима)
# Лаг 446: p-значение = 0.0000 (значима)
# Лаг 447: p-значение = 0.0000 (значима)
# Лаг 448: p-значение = 0.0000 (значима)
# Лаг 449: p-значение = 0.0000 (значима)
# Лаг 450: p-значение = 0.0000 (значима)
# Лаг 451: p-значение = 0.0000 (значима)
# Лаг 452: p-значение = 0.0000 (значима)
# Лаг 453: p-значение = 0.0000 (значима)
# Лаг 454: p-значение = 0.0000 (значима)
# Лаг 455: p-значение = 0.0000 (значима)
# Лаг 456: p-значение = 0.0000 (значима)
# Лаг 457: p-значение = 0.0000 (значима)
# Лаг 458: p-значение = 0.0000 (значима)
# Лаг 459: p-значение = 0.0000 (значима)
# Лаг 460: p-значение = 0.0000 (значима)
# Лаг 461: p-значение = 0.0000 (значима)
# Лаг 462: p-значение = 0.0000 (значима)
# Лаг 463: p-значение = 0.0000 (значима)
# Лаг 464: p-значение = 0.0000 (значима)
# Лаг 465: p-значение = 0.0000 (значима)
# Лаг 466: p-значение = 0.0000 (значима)
# Лаг 467: p-значение = 0.0000 (значима)
# Лаг 468: p-значение = 0.0000 (значима)
# Лаг 469: p-значение = 0.0000 (значима)
# Лаг 470: p-значение = 0.0000 (значима)
# Лаг 471: p-значение = 0.0000 (значима)
# Лаг 472: p-значение = 0.0000 (значима)
# Лаг 473: p-значение = 0.0000 (значима)
# Лаг 474: p-значение = 0.0000 (значима)
# Лаг 475: p-значение = 0.0000 (значима)
# Лаг 476: p-значение = 0.0000 (значима)
# Лаг 477: p-значение = 0.0000 (значима)
# Лаг 478: p-значение = 0.0000 (значима)
# Лаг 479: p-значение = 0.0000 (значима)
# Лаг 480: p-значение = 0.0000 (значима)
# Лаг 481: p-значение = 0.0000 (значима)
# Лаг 482: p-значение = 0.0000 (значима)
# Лаг 483: p-значение = 0.0000 (значима)
# Лаг 484: p-значение = 0.0000 (значима)
# Лаг 485: p-значение = 0.0000 (значима)
# Лаг 486: p-значение = 0.0000 (значима)
# Лаг 487: p-значение = 0.0000 (значима)
# Лаг 488: p-значение = 0.0000 (значима)
# Лаг 489: p-значение = 0.0000 (значима)
# Лаг 490: p-значение = 0.0000 (значима)
# Лаг 491: p-значение = 0.0000 (значима)
# Лаг 492: p-значение = 0.0000 (значима)
# Лаг 493: p-значение = 0.0000 (значима)
# Лаг 494: p-значение = 0.0000 (значима)
# Лаг 495: p-значение = 0.0000 (значима)
# Лаг 496: p-значение = 0.0000 (значима)
# Лаг 497: p-значение = 0.0000 (значима)
# Лаг 498: p-значение = 0.0000 (значима)
# Лаг 499: p-значение = 0.0000 (значима)
# Лаг 500: p-значение = 0.0000 (значима)
# Лаг 501: p-значение = 0.0000 (значима)
# Лаг 502: p-значение = 0.0000 (значима)
# Лаг 503: p-значение = 0.0000 (значима)
# Лаг 504: p-значение = 0.0000 (значима)
# Лаг 505: p-значение = 0.0000 (значима)
# Лаг 506: p-значение = 0.0000 (значима)
# Лаг 507: p-значение = 0.0000 (значима)
# Лаг 508: p-значение = 0.0000 (значима)
# Лаг 509: p-значение = 0.0000 (значима)
# Лаг 510: p-значение = 0.0000 (значима)
# Лаг 511: p-значение = 0.0000 (значима)
# Лаг 512: p-значение = 0.0000 (значима)
# Лаг 513: p-значение = 0.0000 (значима)
# Лаг 514: p-значение = 0.0000 (значима)
# Лаг 515: p-значение = 0.0000 (значима)
# Лаг 516: p-значение = 0.0000 (значима)
# Лаг 517: p-значение = 0.0000 (значима)
# Лаг 518: p-значение = 0.0000 (значима)
# Лаг 519: p-значение = 0.0000 (значима)
# Лаг 520: p-значение = 0.0000 (значима)
# Лаг 521: p-значение = 0.0000 (значима)
# Лаг 522: p-значение = 0.0000 (значима)
# Лаг 523: p-значение = 0.0000 (значима)
# Лаг 524: p-значение = 0.0000 (значима)
# Лаг 525: p-значение = 0.0000 (значима)
# Лаг 526: p-значение = 0.0000 (значима)
# Лаг 527: p-значение = 0.0000 (значима)
# Лаг 528: p-значение = 0.0000 (значима)
# Лаг 529: p-значение = 0.0000 (значима)
# Лаг 530: p-значение = 0.0000 (значима)
# Лаг 531: p-значение = 0.0000 (значима)
# Лаг 532: p-значение = 0.0000 (значима)
# Лаг 533: p-значение = 0.0000 (значима)
# Лаг 534: p-значение = 0.0000 (значима)
# Лаг 535: p-значение = 0.0000 (значима)
# Лаг 536: p-значение = 0.0000 (значима)
# Лаг 537: p-значение = 0.0000 (значима)
# Лаг 538: p-значение = 0.0000 (значима)
# Лаг 539: p-значение = 0.0000 (значима)
# Лаг 540: p-значение = 0.0000 (значима)
# Лаг 541: p-значение = 0.0000 (значима)
# Лаг 542: p-значение = 0.0000 (значима)
# Лаг 543: p-значение = 0.0000 (значима)
# Лаг 544: p-значение = 0.0000 (значима)
# Лаг 545: p-значение = 0.0000 (значима)
# Лаг 546: p-значение = 0.0000 (значима)
# Лаг 547: p-значение = 0.0000 (значима)
# Лаг 548: p-значение = 0.0000 (значима)
# Лаг 549: p-значение = 0.0000 (значима)
# Лаг 550: p-значение = 0.0000 (значима)
# Лаг 551: p-значение = 0.0000 (значима)
# Лаг 552: p-значение = 0.0000 (значима)
# Лаг 553: p-значение = 0.0000 (значима)
# Лаг 554: p-значение = 0.0000 (значима)
# Лаг 555: p-значение = 0.0000 (значима)
# Лаг 556: p-значение = 0.0000 (значима)
# Лаг 557: p-значение = 0.0000 (значима)
# Лаг 558: p-значение = 0.0000 (значима)
# Лаг 559: p-значение = 0.0000 (значима)
# Лаг 560: p-значение = 0.0000 (значима)
# Лаг 561: p-значение = 0.0000 (значима)
# Лаг 562: p-значение = 0.0000 (значима)
# Лаг 563: p-значение = 0.0000 (значима)
# Лаг 564: p-значение = 0.0000 (значима)
# Лаг 565: p-значение = 0.0000 (значима)
# Лаг 566: p-значение = 0.0000 (значима)
# Лаг 567: p-значение = 0.0000 (значима)
# Лаг 568: p-значение = 0.0000 (значима)
# Лаг 569: p-значение = 0.0000 (значима)
# Лаг 570: p-значение = 0.0000 (значима)
# Лаг 571: p-значение = 0.0000 (значима)
# Лаг 572: p-значение = 0.0000 (значима)
# Лаг 573: p-значение = 0.0000 (значима)
# Лаг 574: p-значение = 0.0000 (значима)
# Лаг 575: p-значение = 0.0000 (значима)
# Лаг 576: p-значение = 0.0000 (значима)
# Лаг 577: p-значение = 0.0000 (значима)
# Лаг 578: p-значение = 0.0000 (значима)
# Лаг 579: p-значение = 0.0000 (значима)
# Лаг 580: p-значение = 0.0000 (значима)
# Лаг 581: p-значение = 0.0000 (значима)
# Лаг 582: p-значение = 0.0000 (значима)
# Лаг 583: p-значение = 0.0000 (значима)
# Лаг 584: p-значение = 0.0000 (значима)
# Лаг 585: p-значение = 0.0000 (значима)
# Лаг 586: p-значение = 0.0000 (значима)
# Лаг 587: p-значение = 0.0000 (значима)
# Лаг 588: p-значение = 0.0000 (значима)
# Лаг 589: p-значение = 0.0000 (значима)
# Лаг 590: p-значение = 0.0000 (значима)
# Лаг 591: p-значение = 0.0000 (значима)
# Лаг 592: p-значение = 0.0000 (значима)
# Лаг 593: p-значение = 0.0000 (значима)
# Лаг 594: p-значение = 0.0000 (значима)
# Лаг 595: p-значение = 0.0000 (значима)
# Лаг 596: p-значение = 0.0000 (значима)
# Лаг 597: p-значение = 0.0000 (значима)
# Лаг 598: p-значение = 0.0000 (значима)
# Лаг 599: p-значение = 0.0000 (значима)
# Лаг 600: p-значение = 0.0000 (значима)
# Лаг 601: p-значение = 0.0000 (значима)
# Лаг 602: p-значение = 0.0000 (значима)
# Лаг 603: p-значение = 0.0000 (значима)
# Лаг 604: p-значение = 0.0000 (значима)
# Лаг 605: p-значение = 0.0000 (значима)
# Лаг 606: p-значение = 0.0000 (значима)
# Лаг 607: p-значение = 0.0000 (значима)
# Лаг 608: p-значение = 0.0000 (значима)
# Лаг 609: p-значение = 0.0000 (значима)
# Лаг 610: p-значение = 0.0000 (значима)
# Лаг 611: p-значение = 0.0000 (значима)
# Лаг 612: p-значение = 0.0000 (значима)
# Лаг 613: p-значение = 0.0000 (значима)
# Лаг 614: p-значение = 0.0000 (значима)
# Лаг 615: p-значение = 0.0000 (значима)
# Лаг 616: p-значение = 0.0000 (значима)
# Лаг 617: p-значение = 0.0000 (значима)
# Лаг 618: p-значение = 0.0000 (значима)
# Лаг 619: p-значение = 0.0000 (значима)
# Лаг 620: p-значение = 0.0000 (значима)
# Лаг 621: p-значение = 0.0000 (значима)
# Лаг 622: p-значение = 0.0000 (значима)
# Лаг 623: p-значение = 0.0000 (значима)
# Лаг 624: p-значение = 0.0000 (значима)
# Лаг 625: p-значение = 0.0000 (значима)
# Лаг 626: p-значение = 0.0000 (значима)
# Лаг 627: p-значение = 0.0000 (значима)
# Лаг 628: p-значение = 0.0000 (значима)
# Лаг 629: p-значение = 0.0000 (значима)
# Лаг 630: p-значение = 0.0000 (значима)
# Лаг 631: p-значение = 0.0000 (значима)
# Лаг 632: p-значение = 0.0000 (значима)
# Лаг 633: p-значение = 0.0000 (значима)
# Лаг 634: p-значение = 0.0000 (значима)
# Лаг 635: p-значение = 0.0000 (значима)
# Лаг 636: p-значение = 0.0000 (значима)
# Лаг 637: p-значение = 0.0000 (значима)
# Лаг 638: p-значение = 0.0000 (значима)
# Лаг 639: p-значение = 0.0000 (значима)
# Лаг 640: p-значение = 0.0000 (значима)
# Лаг 641: p-значение = 0.0000 (значима)
# Лаг 642: p-значение = 0.0000 (значима)
# Лаг 643: p-значение = 0.0000 (значима)
# Лаг 644: p-значение = 0.0000 (значима)
# Лаг 645: p-значение = 0.0000 (значима)
# Лаг 646: p-значение = 0.0000 (значима)
# Лаг 647: p-значение = 0.0000 (значима)
# Лаг 648: p-значение = 0.0000 (значима)
# Лаг 649: p-значение = 0.0000 (значима)
# Лаг 650: p-значение = 0.0000 (значима)
# Лаг 651: p-значение = 0.0000 (значима)
# Лаг 652: p-значение = 0.0000 (значима)
# Лаг 653: p-значение = 0.0000 (значима)
# Лаг 654: p-значение = 0.0000 (значима)
# Лаг 655: p-значение = 0.0000 (значима)
# Лаг 656: p-значение = 0.0000 (значима)
# Лаг 657: p-значение = 0.0000 (значима)
# Лаг 658: p-значение = 0.0000 (значима)
# Лаг 659: p-значение = 0.0000 (значима)
# Лаг 660: p-значение = 0.0000 (значима)
# Лаг 661: p-значение = 0.0000 (значима)
# Лаг 662: p-значение = 0.0000 (значима)
# Лаг 663: p-значение = 0.0000 (значима)
# Лаг 664: p-значение = 0.0000 (значима)
# Лаг 665: p-значение = 0.0000 (значима)
# Лаг 666: p-значение = 0.0000 (значима)
# Лаг 667: p-значение = 0.0000 (значима)
# Лаг 668: p-значение = 0.0000 (значима)
# Лаг 669: p-значение = 0.0000 (значима)
# Лаг 670: p-значение = 0.0000 (значима)
# Лаг 671: p-значение = 0.0000 (значима)
# Лаг 672: p-значение = 0.0000 (значима)
# Лаг 673: p-значение = 0.0000 (значима)
# Лаг 674: p-значение = 0.0000 (значима)
# Лаг 675: p-значение = 0.0000 (значима)
# Лаг 676: p-значение = 0.0000 (значима)
# Лаг 677: p-значение = 0.0000 (значима)
# Лаг 678: p-значение = 0.0000 (значима)
# Лаг 679: p-значение = 0.0000 (значима)
# Лаг 680: p-значение = 0.0000 (значима)
# Лаг 681: p-значение = 0.0000 (значима)
# Лаг 682: p-значение = 0.0000 (значима)
# Лаг 683: p-значение = 0.0000 (значима)
# Лаг 684: p-значение = 0.0000 (значима)
# Лаг 685: p-значение = 0.0000 (значима)
# Лаг 686: p-значение = 0.0000 (значима)
# Лаг 687: p-значение = 0.0000 (значима)
# Лаг 688: p-значение = 0.0000 (значима)
# Лаг 689: p-значение = 0.0000 (значима)
# Лаг 690: p-значение = 0.0000 (значима)
# Лаг 691: p-значение = 0.0000 (значима)
# Лаг 692: p-значение = 0.0000 (значима)
# Лаг 693: p-значение = 0.0000 (значима)
# Лаг 694: p-значение = 0.0000 (значима)
# Лаг 695: p-значение = 0.0000 (значима)
# Лаг 696: p-значение = 0.0000 (значима)
# Лаг 697: p-значение = 0.0000 (значима)
# Лаг 698: p-значение = 0.0000 (значима)
# Лаг 699: p-значение = 0.0000 (значима)
# Лаг 700: p-значение = 0.0000 (значима)
# Лаг 701: p-значение = 0.0000 (значима)
# Лаг 702: p-значение = 0.0000 (значима)
# Лаг 703: p-значение = 0.0000 (значима)
# Лаг 704: p-значение = 0.0000 (значима)
# Лаг 705: p-значение = 0.0000 (значима)
# Лаг 706: p-значение = 0.0000 (значима)
# Лаг 707: p-значение = 0.0000 (значима)
# Лаг 708: p-значение = 0.0000 (значима)
# Лаг 709: p-значение = 0.0000 (значима)
# Лаг 710: p-значение = 0.0000 (значима)
# Лаг 711: p-значение = 0.0000 (значима)
# Лаг 712: p-значение = 0.0000 (значима)
# Лаг 713: p-значение = 0.0000 (значима)
# Лаг 714: p-значение = 0.0000 (значима)
# Лаг 715: p-значение = 0.0000 (значима)
# Лаг 716: p-значение = 0.0000 (значима)
# Лаг 717: p-значение = 0.0000 (значима)
# Лаг 718: p-значение = 0.0000 (значима)
# Лаг 719: p-значение = 0.0000 (значима)
# Лаг 720: p-значение = 0.0000 (значима)
# Лаг 721: p-значение = 0.0000 (значима)
# Лаг 722: p-значение = 0.0000 (значима)
# Лаг 723: p-значение = 0.0000 (значима)
# Лаг 724: p-значение = 0.0000 (значима)
# Лаг 725: p-значение = 0.0000 (значима)
# Лаг 726: p-значение = 0.0000 (значима)
# Лаг 727: p-значение = 0.0000 (значима)
# Лаг 728: p-значение = 0.0000 (значима)
# Лаг 729: p-значение = 0.0000 (значима)
# Лаг 730: p-значение = 0.0000 (значима)
# Лаг 731: p-значение = 0.0000 (значима)
# Лаг 732: p-значение = 0.0000 (значима)
# Лаг 733: p-значение = 0.0000 (значима)
# Лаг 734: p-значение = 0.0000 (значима)
# Лаг 735: p-значение = 0.0000 (значима)
# Лаг 736: p-значение = 0.0000 (значима)
# Лаг 737: p-значение = 0.0000 (значима)
# Лаг 738: p-значение = 0.0000 (значима)
# Лаг 739: p-значение = 0.0000 (значима)
# Лаг 740: p-значение = 0.0000 (значима)
# Лаг 741: p-значение = 0.0000 (значима)
# Лаг 742: p-значение = 0.0000 (значима)
# Лаг 743: p-значение = 0.0000 (значима)
# Лаг 744: p-значение = 0.0000 (значима)
# Лаг 745: p-значение = 0.0000 (значима)
# Лаг 746: p-значение = 0.0000 (значима)
# Лаг 747: p-значение = 0.0000 (значима)
# Лаг 748: p-значение = 0.0000 (значима)
# Лаг 749: p-значение = 0.0000 (значима)
# Лаг 750: p-значение = 0.0000 (значима)
# Лаг 751: p-значение = 0.0000 (значима)
# Лаг 752: p-значение = 0.0000 (значима)
# Лаг 753: p-значение = 0.0000 (значима)
# Лаг 754: p-значение = 0.0000 (значима)
# Лаг 755: p-значение = 0.0000 (значима)
# Лаг 756: p-значение = 0.0000 (значима)
# Лаг 757: p-значение = 0.0000 (значима)
# Лаг 758: p-значение = 0.0000 (значима)
# Лаг 759: p-значение = 0.0000 (значима)
# Лаг 760: p-значение = 0.0000 (значима)
# Лаг 761: p-значение = 0.0000 (значима)
# Лаг 762: p-значение = 0.0000 (значима)
# Лаг 763: p-значение = 0.0000 (значима)
# Лаг 764: p-значение = 0.0000 (значима)
# Лаг 765: p-значение = 0.0000 (значима)
# Лаг 766: p-значение = 0.0000 (значима)
# Лаг 767: p-значение = 0.0000 (значима)
# Лаг 768: p-значение = 0.0000 (значима)
# Лаг 769: p-значение = 0.0000 (значима)
# Лаг 770: p-значение = 0.0000 (значима)
# Лаг 771: p-значение = 0.0000 (значима)
# Лаг 772: p-значение = 0.0000 (значима)
# Лаг 773: p-значение = 0.0000 (значима)
# Лаг 774: p-значение = 0.0000 (значима)
# Лаг 775: p-значение = 0.0000 (значима)
# Лаг 776: p-значение = 0.0000 (значима)
# Лаг 777: p-значение = 0.0000 (значима)
# Лаг 778: p-значение = 0.0000 (значима)
# Лаг 779: p-значение = 0.0000 (значима)
# Лаг 780: p-значение = 0.0000 (значима)
# Лаг 781: p-значение = 0.0000 (значима)
# Лаг 782: p-значение = 0.0000 (значима)
# Лаг 783: p-значение = 0.0000 (значима)
# Лаг 784: p-значение = 0.0000 (значима)
# Лаг 785: p-значение = 0.0000 (значима)
# Лаг 786: p-значение = 0.0000 (значима)
# Лаг 787: p-значение = 0.0000 (значима)
# Лаг 788: p-значение = 0.0000 (значима)
# Лаг 789: p-значение = 0.0000 (значима)
# Лаг 790: p-значение = 0.0000 (значима)
# Лаг 791: p-значение = 0.0000 (значима)
# Лаг 792: p-значение = 0.0000 (значима)
# Лаг 793: p-значение = 0.0000 (значима)
# Лаг 794: p-значение = 0.0000 (значима)
# Лаг 795: p-значение = 0.0000 (значима)
# Лаг 796: p-значение = 0.0000 (значима)
# Лаг 797: p-значение = 0.0000 (значима)
# Лаг 798: p-значение = 0.0000 (значима)
# Лаг 799: p-значение = 0.0000 (значима)
# Лаг 800: p-значение = 0.0000 (значима)
# Лаг 801: p-значение = 0.0000 (значима)
# Лаг 802: p-значение = 0.0000 (значима)
# Лаг 803: p-значение = 0.0000 (значима)
# Лаг 804: p-значение = 0.0000 (значима)
# Лаг 805: p-значение = 0.0000 (значима)
# Лаг 806: p-значение = 0.0000 (значима)
# Лаг 807: p-значение = 0.0000 (значима)
# Лаг 808: p-значение = 0.0000 (значима)
# Лаг 809: p-значение = 0.0000 (значима)
# Лаг 810: p-значение = 0.0000 (значима)
# Лаг 811: p-значение = 0.0000 (значима)
# Лаг 812: p-значение = 0.0000 (значима)
# Лаг 813: p-значение = 0.0000 (значима)
# Лаг 814: p-значение = 0.0000 (значима)
# Лаг 815: p-значение = 0.0000 (значима)
# Лаг 816: p-значение = 0.0000 (значима)
# Лаг 817: p-значение = 0.0000 (значима)
# Лаг 818: p-значение = 0.0000 (значима)
# Лаг 819: p-значение = 0.0000 (значима)
# Лаг 820: p-значение = 0.0000 (значима)
# Лаг 821: p-значение = 0.0000 (значима)
# Лаг 822: p-значение = 0.0000 (значима)
# Лаг 823: p-значение = 0.0000 (значима)
# Лаг 824: p-значение = 0.0000 (значима)
# Лаг 825: p-значение = 0.0000 (значима)
# Лаг 826: p-значение = 0.0000 (значима)
# Лаг 827: p-значение = 0.0000 (значима)
# Лаг 828: p-значение = 0.0000 (значима)
# Лаг 829: p-значение = 0.0000 (значима)
# Лаг 830: p-значение = 0.0000 (значима)
# Лаг 831: p-значение = 0.0000 (значима)
# Лаг 832: p-значение = 0.0000 (значима)
# Лаг 833: p-значение = 0.0000 (значима)
# Лаг 834: p-значение = 0.0000 (значима)
# Лаг 835: p-значение = 0.0000 (значима)
# Лаг 836: p-значение = 0.0000 (значима)
# Лаг 837: p-значение = 0.0000 (значима)
# Лаг 838: p-значение = 0.0000 (значима)
# Лаг 839: p-значение = 0.0000 (значима)
# Лаг 840: p-значение = 0.0000 (значима)
# Лаг 841: p-значение = 0.0000 (значима)
# Лаг 842: p-значение = 0.0000 (значима)
# Лаг 843: p-значение = 0.0000 (значима)
# Лаг 844: p-значение = 0.0000 (значима)
# Лаг 845: p-значение = 0.0000 (значима)
# Лаг 846: p-значение = 0.0000 (значима)
# Лаг 847: p-значение = 0.0000 (значима)
# Лаг 848: p-значение = 0.0000 (значима)
# Лаг 849: p-значение = 0.0000 (значима)
# Лаг 850: p-значение = 0.0000 (значима)
# Лаг 851: p-значение = 0.0000 (значима)
# Лаг 852: p-значение = 0.0000 (значима)
# Лаг 853: p-значение = 0.0000 (значима)
# Лаг 854: p-значение = 0.0000 (значима)
# Лаг 855: p-значение = 0.0000 (значима)
# Лаг 856: p-значение = 0.0000 (значима)
# Лаг 857: p-значение = 0.0000 (значима)
# Лаг 858: p-значение = 0.0000 (значима)
# Лаг 859: p-значение = 0.0000 (значима)
# Лаг 860: p-значение = 0.0000 (значима)
# Лаг 861: p-значение = 0.0000 (значима)
# Лаг 862: p-значение = 0.0000 (значима)
# Лаг 863: p-значение = 0.0000 (значима)
# Лаг 864: p-значение = 0.0000 (значима)
# Лаг 865: p-значение = 0.0000 (значима)
# Лаг 866: p-значение = 0.0000 (значима)
# Лаг 867: p-значение = 0.0000 (значима)
# Лаг 868: p-значение = 0.0000 (значима)
# Лаг 869: p-значение = 0.0000 (значима)
# Лаг 870: p-значение = 0.0000 (значима)
# Лаг 871: p-значение = 0.0000 (значима)
# Лаг 872: p-значение = 0.0000 (значима)
# Лаг 873: p-значение = 0.0000 (значима)
# Лаг 874: p-значение = 0.0000 (значима)
# Лаг 875: p-значение = 0.0000 (значима)
# Лаг 876: p-значение = 0.0000 (значима)
# Лаг 877: p-значение = 0.0000 (значима)
# Лаг 878: p-значение = 0.0000 (значима)
# Лаг 879: p-значение = 0.0000 (значима)
# Лаг 880: p-значение = 0.0000 (значима)
# Лаг 881: p-значение = 0.0000 (значима)
# Лаг 882: p-значение = 0.0000 (значима)
# Лаг 883: p-значение = 0.0000 (значима)
# Лаг 884: p-значение = 0.0000 (значима)
# Лаг 885: p-значение = 0.0000 (значима)
# Лаг 886: p-значение = 0.0000 (значима)
# Лаг 887: p-значение = 0.0000 (значима)
# Лаг 888: p-значение = 0.0000 (значима)
# Лаг 889: p-значение = 0.0000 (значима)
# Лаг 890: p-значение = 0.0000 (значима)
# Лаг 891: p-значение = 0.0000 (значима)
# Лаг 892: p-значение = 0.0000 (значима)
# Лаг 893: p-значение = 0.0000 (значима)
# Лаг 894: p-значение = 0.0000 (значима)
# Лаг 895: p-значение = 0.0000 (значима)
# Лаг 896: p-значение = 0.0000 (значима)
# Лаг 897: p-значение = 0.0000 (значима)
# Лаг 898: p-значение = 0.0000 (значима)
# Лаг 899: p-значение = 0.0000 (значима)
# Лаг 900: p-значение = 0.0000 (значима)
# Лаг 901: p-значение = 0.0000 (значима)
# Лаг 902: p-значение = 0.0000 (значима)
# Лаг 903: p-значение = 0.0000 (значима)
# Лаг 904: p-значение = 0.0000 (значима)
# Лаг 905: p-значение = 0.0000 (значима)
# Лаг 906: p-значение = 0.0000 (значима)
# Лаг 907: p-значение = 0.0000 (значима)
# Лаг 908: p-значение = 0.0000 (значима)
# Лаг 909: p-значение = 0.0000 (значима)
# Лаг 910: p-значение = 0.0000 (значима)
# Лаг 911: p-значение = 0.0000 (значима)
# Лаг 912: p-значение = 0.0000 (значима)
# Лаг 913: p-значение = 0.0000 (значима)
# Лаг 914: p-значение = 0.0000 (значима)
# Лаг 915: p-значение = 0.0000 (значима)
# Лаг 916: p-значение = 0.0000 (значима)
# Лаг 917: p-значение = 0.0000 (значима)
# Лаг 918: p-значение = 0.0000 (значима)
# Лаг 919: p-значение = 0.0000 (значима)
# Лаг 920: p-значение = 0.0000 (значима)
# Лаг 921: p-значение = 0.0000 (значима)
# Лаг 922: p-значение = 0.0000 (значима)
# Лаг 923: p-значение = 0.0000 (значима)
# Лаг 924: p-значение = 0.0000 (значима)
# Лаг 925: p-значение = 0.0000 (значима)
# Лаг 926: p-значение = 0.0000 (значима)
# Лаг 927: p-значение = 0.0000 (значима)
# Лаг 928: p-значение = 0.0000 (значима)
# Лаг 929: p-значение = 0.0000 (значима)
# Лаг 930: p-значение = 0.0000 (значима)
# Лаг 931: p-значение = 0.0000 (значима)
# Лаг 932: p-значение = 0.0000 (значима)
# Лаг 933: p-значение = 0.0000 (значима)
# Лаг 934: p-значение = 0.0000 (значима)
# Лаг 935: p-значение = 0.0000 (значима)
# Лаг 936: p-значение = 0.0000 (значима)
# Лаг 937: p-значение = 0.0000 (значима)
# Лаг 938: p-значение = 0.0000 (значима)
# Лаг 939: p-значение = 0.0000 (значима)
# Лаг 940: p-значение = 0.0000 (значима)
# Лаг 941: p-значение = 0.0000 (значима)
# Лаг 942: p-значение = 0.0000 (значима)
# Лаг 943: p-значение = 0.0000 (значима)
# Лаг 944: p-значение = 0.0000 (значима)
# Лаг 945: p-значение = 0.0000 (значима)
# Лаг 946: p-значение = 0.0000 (значима)
# Лаг 947: p-значение = 0.0000 (значима)
# Лаг 948: p-значение = 0.0000 (значима)
# Лаг 949: p-значение = 0.0000 (значима)
# Лаг 950: p-значение = 0.0000 (значима)
# Лаг 951: p-значение = 0.0000 (значима)
# Лаг 952: p-значение = 0.0000 (значима)
# Лаг 953: p-значение = 0.0000 (значима)
# Лаг 954: p-значение = 0.0000 (значима)
# Лаг 955: p-значение = 0.0000 (значима)
# Лаг 956: p-значение = 0.0000 (значима)
# Лаг 957: p-значение = 0.0000 (значима)
# Лаг 958: p-значение = 0.0000 (значима)
# Лаг 959: p-значение = 0.0000 (значима)
# Лаг 960: p-значение = 0.0000 (значима)
# Лаг 961: p-значение = 0.0000 (значима)
# Лаг 962: p-значение = 0.0000 (значима)
# Лаг 963: p-значение = 0.0000 (значима)
# Лаг 964: p-значение = 0.0000 (значима)
# Лаг 965: p-значение = 0.0000 (значима)
# Лаг 966: p-значение = 0.0000 (значима)
# Лаг 967: p-значение = 0.0000 (значима)
# Лаг 968: p-значение = 0.0000 (значима)
# Лаг 969: p-значение = 0.0000 (значима)
# Лаг 970: p-значение = 0.0000 (значима)
# Лаг 971: p-значение = 0.0000 (значима)
# Лаг 972: p-значение = 0.0000 (значима)
# Лаг 973: p-значение = 0.0000 (значима)
# Лаг 974: p-значение = 0.0000 (значима)
# Лаг 975: p-значение = 0.0000 (значима)
# Лаг 976: p-значение = 0.0000 (значима)
# Лаг 977: p-значение = 0.0000 (значима)
# Лаг 978: p-значение = 0.0000 (значима)
# Лаг 979: p-значение = 0.0000 (значима)
# Лаг 980: p-значение = 0.0000 (значима)
# Лаг 981: p-значение = 0.0000 (значима)
# Лаг 982: p-значение = 0.0000 (значима)
# Лаг 983: p-значение = 0.0000 (значима)
# Лаг 984: p-значение = 0.0000 (значима)
# Лаг 985: p-значение = 0.0000 (значима)
# Лаг 986: p-значение = 0.0000 (значима)
# Лаг 987: p-значение = 0.0000 (значима)
# Лаг 988: p-значение = 0.0000 (значима)
# Лаг 989: p-значение = 0.0000 (значима)
# Лаг 990: p-значение = 0.0000 (значима)
# Лаг 991: p-значение = 0.0000 (значима)
# Лаг 992: p-значение = 0.0000 (значима)
# Лаг 993: p-значение = 0.0000 (значима)
# Лаг 994: p-значение = 0.0000 (значима)
# Лаг 995: p-значение = 0.0000 (значима)
# Лаг 996: p-значение = 0.0000 (значима)
# Лаг 997: p-значение = 0.0000 (значима)
# Лаг 998: p-значение = 0.0000 (значима)
# Лаг 999: p-значение = 0.0000 (значима)
# Лаг 1000: p-значение = 0.0000 (значима)

# %% [markdown]
# 1.5) Автокорреляционная функция
#
# Автокорреляционная функция (АКФ) — зависимость взаимосвязи между функцией и её сдвинутой по аргументу функции копией от величины сдвига.

# %% [markdown]
# 1.4) ACF-график (визуализация автокорреляционной функции) для наглядности

# %%
def visualize_acf(df, column, lags):
    """
    Строит график автокорреляционной функции (ACF) для заданной колонки датафрейма.

    Параметры:
        df (pd.DataFrame): Входной датафрейм.
        column (str): Название колонки для анализа.
        lags (int) | (array_like): Лаги для расчета ACF

    Выводит ACF-график.
    """
    if column not in df.columns:
        raise ValueError(f"Колонка '{column}' отсутствует в датафрейме.")

    plt.figure(figsize=(10, 6))
    plot_acf(df[column].dropna(), lags=lags)
    plt.title(f"Коррелограмма")
    plt.xlabel("Лаги")
    plt.ylabel("Автокорреляция")
    plt.grid()
    plt.show()

# %%
lags = np.array([5, 10, 20, 50, 100, 500, 700, 1000, 2000])
visualize_acf(data.df, column="close", lags=lags)
