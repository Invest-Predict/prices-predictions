# %%
from catboost import MultiTargetCustomMetric, MultiTargetCustomObjective
import numpy as np


class HundredDollarLoss(MultiTargetCustomObjective):
    def calc_ders_multi(self, approxes, targets, weight):
        """
        approxes: logits vector x (num_securities, )
        targets: precomputed v vector (num_securities, )
        weight: data point weight
        """
        m = np.maximum(np.max(approxes), 0.)
        exp_x = np.exp(approxes - m)
        s_tilde = exp_x / (np.sum(exp_x) + np.exp(-m))

        v_s_tilde = targets * s_tilde
        grad = v_s_tilde - np.sum(v_s_tilde) * s_tilde

        M = np.outer(grad, s_tilde)
        hess = np.diag(grad) - M - M.T

        return -grad * weight, -hess * weight
    

class TwoHundredDollarLoss(MultiTargetCustomObjective):
    def calc_ders_multi(self, approxes, targets, weight):
        """
        approxes: logits vector x (num_securities, )
        targets: precomputed v vector (num_securities, )
        weight: data point weight
        """
        m = np.maximum(np.max(approxes), 0.)
        exp_x = np.exp(approxes - m)
        s_tilde = exp_x / (np.sum(exp_x) + np.exp(-m))

        v_s_tilde = targets * s_tilde
        sum_v_s_tilde = np.sum(v_s_tilde)
        grad = (v_s_tilde - sum_v_s_tilde * s_tilde) / (1. - sum_v_s_tilde)

        M = np.outer(grad, s_tilde)
        hess = np.outer(grad, grad) + np.diag(grad) - M - M.T

        return -grad * weight, -hess * weight
    

class HundredDollarMetric(MultiTargetCustomMetric):
    def get_final_error(self, error, weight):
        return np.exp(error / weight)

    def is_max_optimal(self):
        return True

    def evaluate(self, approxes, targets, weights):
        """
        approxes: tuple of logits vectors x (num_securities, dataset_size)
        targets: tuple of precomputed v vectors (num_securities, dataset_size)
        weights: data point weights array (dataset_size, ) or None
        """
        approxes = np.vstack(approxes)
        # numba doesn't know np.max(approxes, axis=0)...
        m = np.zeros(approxes.shape[1])
        for i in range(approxes.shape[1]):
            m[i] = np.max(approxes[:, i])
        exp_x = np.exp(approxes - m)
        s_tilde = exp_x / (np.sum(exp_x, axis=0) + np.exp(-m))
        error_sum = np.sum(np.log1p(-np.sum(s_tilde * np.vstack(targets), axis=0)) * (1. if weights is None else weights))
        weight_sum = approxes.shape[1] if weights is None else np.sum(weights)
        
        return error_sum, weight_sum

# %%
from sklearn.model_selection import train_test_split
from catboost import CatBoost, Pool

# Игрушечный пример
m = 2000
k = 30 # кол-во признаков
n = 10 # кол-во компаний
X = np.random.randn(m, k)
c = np.exp(X[:, :n])
o = np.exp(X[:, -n:])
t = 4e-3
v = (1 + t) - (1 - t) * (c / o)

X_train, X_val, v_train, v_val = train_test_split(X, v, test_size=.1)

# %%
model = CatBoost(dict(
    iterations=1000,
    learning_rate=3.,
    depth=5,
    loss_function=HundredDollarLoss(), 
    verbose=100,
    eval_metric=HundredDollarMetric(),
    l2_leaf_reg=100
))

model.fit(X_train, v_train, eval_set=Pool(X_val, v_val))
# Out:
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# 0:	learn: 2.2954022	test: 2.1627759	best: 2.1627759 (0)	total: 1.38s	remaining: 23m 2s
# 100:	learn: 6.7907700	test: 5.6628679	best: 5.6631621 (99)	total: 4.3s	remaining: 38.3s
# 200:	learn: 7.6825929	test: 6.4984264	best: 6.5009521 (198)	total: 7.17s	remaining: 28.5s
# 300:	learn: 7.9952952	test: 6.6932608	best: 6.6932608 (300)	total: 9.99s	remaining: 23.2s
# 400:	learn: 8.1487283	test: 6.8039011	best: 6.8039011 (400)	total: 12.9s	remaining: 19.2s
# 500:	learn: 8.2227896	test: 6.8330758	best: 6.8406638 (486)	total: 15.7s	remaining: 15.7s
# 600:	learn: 8.2882753	test: 6.8526248	best: 6.8555749 (582)	total: 18.6s	remaining: 12.3s
# 700:	learn: 8.3338089	test: 6.8742759	best: 6.8742759 (700)	total: 21.4s	remaining: 9.12s
# 800:	learn: 8.3739356	test: 6.8974659	best: 6.8974981 (789)	total: 24.2s	remaining: 6s
# 900:	learn: 8.4121239	test: 6.9268035	best: 6.9286633 (894)	total: 27s	remaining: 2.96s
# 999:	learn: 8.4431976	test: 6.9456962	best: 6.9456962 (999)	total: 29.9s	remaining: 0us
#
# bestTest = 6.945696154
# bestIteration = 999

# %%
model = CatBoost(dict(
    iterations=1000,
    learning_rate=3.,
    depth=5,
    loss_function=TwoHundredDollarLoss(), 
    verbose=100,
    eval_metric=HundredDollarMetric(),
    l2_leaf_reg=50
))

model.fit(X_train, v_train, eval_set=Pool(X_val, v_val))
# Out:
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# 0:	learn: 2.4416481	test: 2.2628869	best: 2.2628869 (0)	total: 556ms	remaining: 9m 15s
# 100:	learn: 7.5465752	test: 6.0565079	best: 6.0565079 (100)	total: 3.45s	remaining: 30.7s
# 200:	learn: 8.0788778	test: 6.5203030	best: 6.5203030 (200)	total: 6.3s	remaining: 25s
# 300:	learn: 8.2462878	test: 6.6317239	best: 6.6338972 (299)	total: 9.19s	remaining: 21.3s
# 400:	learn: 8.3537230	test: 6.7192960	best: 6.7192960 (400)	total: 12s	remaining: 18s
# 500:	learn: 8.4312422	test: 6.7850033	best: 6.7850033 (500)	total: 14.9s	remaining: 14.8s
# 600:	learn: 8.4822515	test: 6.8476646	best: 6.8476646 (600)	total: 17.7s	remaining: 11.8s
# 700:	learn: 8.5239605	test: 6.9024472	best: 6.9029902 (697)	total: 20.6s	remaining: 8.77s
# 800:	learn: 8.5570660	test: 6.9437441	best: 6.9437441 (800)	total: 23.4s	remaining: 5.81s
# 900:	learn: 8.5789611	test: 6.9708547	best: 6.9710909 (899)	total: 26.3s	remaining: 2.88s
# 999:	learn: 8.5973774	test: 6.9917425	best: 6.9919524 (998)	total: 29.1s	remaining: 0us
#
# bestTest = 6.991952399
# bestIteration = 998
#
# Shrink model to first 999 iterations.

# %%
import pandas as pd
from datetime import datetime
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

names = ['Tatneft', 'Bashneft', 'Gazprom', 'Lukoil', 'Novatek', 'Rosneft']
start_date = datetime(2024, 1, 1)
end_date = datetime(2024, 12, 31)

dfs = []

for name in names:
    df = pd.read_csv(f"../../datasets/{name}_10_min.csv")
    df.utc = pd.to_datetime(df.utc).dt.tz_localize(None)
    df = df[df.utc >= start_date].set_index('utc').reindex(pd.date_range(start=start_date, end=end_date, freq='10Min'))
    df.close = df.close.ffill(limit_area='inside')
    df.open = df.open.fillna(df.close)
    df.high = df.high.fillna(df.close)
    df.low = df.low.fillna(df.close)
    df.volume = df.volume.fillna(0)

    feats = ['high/close', 'low/close', 'open/close', 'high/low', 'high/open', 'low/open']

    # отношения для текущей свечки
    for feat in feats:
        p1, p2 = feat.split('/')
        df[feat] = df[p1] / df[p2]

    shifts = [1, 2, 3, 4, 5, 6, 9, 12, 18, 24]
    
    for i in shifts:

        # берем попарные лаги close-ов
        df[f'close/close>{i}'] = df.close / df.close.shift(i)
        for j in shifts:
            if j >= i:
                break
            df[f'close>{j}/close>{i}'] = df.close.shift(j) / df.close.shift(i)
        
        # для всех отношений берем шифты
        for feat in feats:
            df[f'({feat})>{i}'] = df[feat].shift(i)
        
        # скользящие средние
        df[f'close/close@{i}'] = df.close / df.close.shift(1).rolling(i).mean()
        df[f'volume/volume@{i}'] = df.volume / df.volume.shift(1).rolling(i).mean()

    df.rename({col: f'{col}[{name}]' for col in df.columns}, axis=1, inplace=True)
    dfs.append(df)

df = pd.concat(dfs, axis=1)
df.dropna(inplace=True)

# добавим попарные по компаниям признаки
diff_feats = ['close/close>1', 'high/low', 'high/close']
for name1 in names:
    for name2 in names:
        if name1 < name2:
            for feat in diff_feats:
                feat1, feat2 = f'{feat}[{name1}]', f'{feat}[{name2}]'
                df[f'{feat1}-{feat2}'] = df[feat1] - df[feat2]

df.columns.to_list()
# Out:
# ['open[Tatneft]',
#  'close[Tatneft]',
#  'high[Tatneft]',
#  'low[Tatneft]',
#  'volume[Tatneft]',
#  'high/close[Tatneft]',
#  'low/close[Tatneft]',
#  'open/close[Tatneft]',
#  'high/low[Tatneft]',
#  'high/open[Tatneft]',
#  'low/open[Tatneft]',
#  'close/close>1[Tatneft]',
#  '(high/close)>1[Tatneft]',
#  '(low/close)>1[Tatneft]',
#  '(open/close)>1[Tatneft]',
#  '(high/low)>1[Tatneft]',
#  '(high/open)>1[Tatneft]',
#  '(low/open)>1[Tatneft]',
#  'close/close@1[Tatneft]',
#  'volume/volume@1[Tatneft]',
#  'close/close>2[Tatneft]',
#  'close>1/close>2[Tatneft]',
#  '(high/close)>2[Tatneft]',
#  '(low/close)>2[Tatneft]',
#  '(open/close)>2[Tatneft]',
#  '(high/low)>2[Tatneft]',
#  '(high/open)>2[Tatneft]',
#  '(low/open)>2[Tatneft]',
#  'close/close@2[Tatneft]',
#  'volume/volume@2[Tatneft]',
#  'close/close>3[Tatneft]',
#  'close>1/close>3[Tatneft]',
#  'close>2/close>3[Tatneft]',
#  '(high/close)>3[Tatneft]',
#  '(low/close)>3[Tatneft]',
#  '(open/close)>3[Tatneft]',
#  '(high/low)>3[Tatneft]',
#  '(high/open)>3[Tatneft]',
#  '(low/open)>3[Tatneft]',
#  'close/close@3[Tatneft]',
#  'volume/volume@3[Tatneft]',
#  'close/close>4[Tatneft]',
#  'close>1/close>4[Tatneft]',
#  'close>2/close>4[Tatneft]',
#  'close>3/close>4[Tatneft]',
#  '(high/close)>4[Tatneft]',
#  '(low/close)>4[Tatneft]',
#  '(open/close)>4[Tatneft]',
#  '(high/low)>4[Tatneft]',
#  '(high/open)>4[Tatneft]',
#  '(low/open)>4[Tatneft]',
#  'close/close@4[Tatneft]',
#  'volume/volume@4[Tatneft]',
#  'close/close>5[Tatneft]',
#  'close>1/close>5[Tatneft]',
#  'close>2/close>5[Tatneft]',
#  'close>3/close>5[Tatneft]',
#  'close>4/close>5[Tatneft]',
#  '(high/close)>5[Tatneft]',
#  '(low/close)>5[Tatneft]',
#  '(open/close)>5[Tatneft]',
#  '(high/low)>5[Tatneft]',
#  '(high/open)>5[Tatneft]',
#  '(low/open)>5[Tatneft]',
#  'close/close@5[Tatneft]',
#  'volume/volume@5[Tatneft]',
#  'close/close>6[Tatneft]',
#  'close>1/close>6[Tatneft]',
#  'close>2/close>6[Tatneft]',
#  'close>3/close>6[Tatneft]',
#  'close>4/close>6[Tatneft]',
#  'close>5/close>6[Tatneft]',
#  '(high/close)>6[Tatneft]',
#  '(low/close)>6[Tatneft]',
#  '(open/close)>6[Tatneft]',
#  '(high/low)>6[Tatneft]',
#  '(high/open)>6[Tatneft]',
#  '(low/open)>6[Tatneft]',
#  'close/close@6[Tatneft]',
#  'volume/volume@6[Tatneft]',
#  'close/close>9[Tatneft]',
#  'close>1/close>9[Tatneft]',
#  'close>2/close>9[Tatneft]',
#  'close>3/close>9[Tatneft]',
#  'close>4/close>9[Tatneft]',
#  'close>5/close>9[Tatneft]',
#  'close>6/close>9[Tatneft]',
#  '(high/close)>9[Tatneft]',
#  '(low/close)>9[Tatneft]',
#  '(open/close)>9[Tatneft]',
#  '(high/low)>9[Tatneft]',
#  '(high/open)>9[Tatneft]',
#  '(low/open)>9[Tatneft]',
#  'close/close@9[Tatneft]',
#  'volume/volume@9[Tatneft]',
#  'close/close>12[Tatneft]',
#  'close>1/close>12[Tatneft]',
#  'close>2/close>12[Tatneft]',
#  'close>3/close>12[Tatneft]',
#  'close>4/close>12[Tatneft]',
#  'close>5/close>12[Tatneft]',
#  'close>6/close>12[Tatneft]',
#  'close>9/close>12[Tatneft]',
#  '(high/close)>12[Tatneft]',
#  '(low/close)>12[Tatneft]',
#  '(open/close)>12[Tatneft]',
#  '(high/low)>12[Tatneft]',
#  '(high/open)>12[Tatneft]',
#  '(low/open)>12[Tatneft]',
#  'close/close@12[Tatneft]',
#  'volume/volume@12[Tatneft]',
#  'close/close>18[Tatneft]',
#  'close>1/close>18[Tatneft]',
#  'close>2/close>18[Tatneft]',
#  'close>3/close>18[Tatneft]',
#  'close>4/close>18[Tatneft]',
#  'close>5/close>18[Tatneft]',
#  'close>6/close>18[Tatneft]',
#  'close>9/close>18[Tatneft]',
#  'close>12/close>18[Tatneft]',
#  '(high/close)>18[Tatneft]',
#  '(low/close)>18[Tatneft]',
#  '(open/close)>18[Tatneft]',
#  '(high/low)>18[Tatneft]',
#  '(high/open)>18[Tatneft]',
#  '(low/open)>18[Tatneft]',
#  'close/close@18[Tatneft]',
#  'volume/volume@18[Tatneft]',
#  'close/close>24[Tatneft]',
#  'close>1/close>24[Tatneft]',
#  'close>2/close>24[Tatneft]',
#  'close>3/close>24[Tatneft]',
#  'close>4/close>24[Tatneft]',
#  'close>5/close>24[Tatneft]',
#  'close>6/close>24[Tatneft]',
#  'close>9/close>24[Tatneft]',
#  'close>12/close>24[Tatneft]',
#  'close>18/close>24[Tatneft]',
#  '(high/close)>24[Tatneft]',
#  '(low/close)>24[Tatneft]',
#  '(open/close)>24[Tatneft]',
#  '(high/low)>24[Tatneft]',
#  '(high/open)>24[Tatneft]',
#  '(low/open)>24[Tatneft]',
#  'close/close@24[Tatneft]',
#  'volume/volume@24[Tatneft]',
#  'open[Bashneft]',
#  'close[Bashneft]',
#  'high[Bashneft]',
#  'low[Bashneft]',
#  'volume[Bashneft]',
#  'high/close[Bashneft]',
#  'low/close[Bashneft]',
#  'open/close[Bashneft]',
#  'high/low[Bashneft]',
#  'high/open[Bashneft]',
#  'low/open[Bashneft]',
#  'close/close>1[Bashneft]',
#  '(high/close)>1[Bashneft]',
#  '(low/close)>1[Bashneft]',
#  '(open/close)>1[Bashneft]',
#  '(high/low)>1[Bashneft]',
#  '(high/open)>1[Bashneft]',
#  '(low/open)>1[Bashneft]',
#  'close/close@1[Bashneft]',
#  'volume/volume@1[Bashneft]',
#  'close/close>2[Bashneft]',
#  'close>1/close>2[Bashneft]',
#  '(high/close)>2[Bashneft]',
#  '(low/close)>2[Bashneft]',
#  '(open/close)>2[Bashneft]',
#  '(high/low)>2[Bashneft]',
#  '(high/open)>2[Bashneft]',
#  '(low/open)>2[Bashneft]',
#  'close/close@2[Bashneft]',
#  'volume/volume@2[Bashneft]',
#  'close/close>3[Bashneft]',
#  'close>1/close>3[Bashneft]',
#  'close>2/close>3[Bashneft]',
#  '(high/close)>3[Bashneft]',
#  '(low/close)>3[Bashneft]',
#  '(open/close)>3[Bashneft]',
#  '(high/low)>3[Bashneft]',
#  '(high/open)>3[Bashneft]',
#  '(low/open)>3[Bashneft]',
#  'close/close@3[Bashneft]',
#  'volume/volume@3[Bashneft]',
#  'close/close>4[Bashneft]',
#  'close>1/close>4[Bashneft]',
#  'close>2/close>4[Bashneft]',
#  'close>3/close>4[Bashneft]',
#  '(high/close)>4[Bashneft]',
#  '(low/close)>4[Bashneft]',
#  '(open/close)>4[Bashneft]',
#  '(high/low)>4[Bashneft]',
#  '(high/open)>4[Bashneft]',
#  '(low/open)>4[Bashneft]',
#  'close/close@4[Bashneft]',
#  'volume/volume@4[Bashneft]',
#  'close/close>5[Bashneft]',
#  'close>1/close>5[Bashneft]',
#  'close>2/close>5[Bashneft]',
#  'close>3/close>5[Bashneft]',
#  'close>4/close>5[Bashneft]',
#  '(high/close)>5[Bashneft]',
#  '(low/close)>5[Bashneft]',
#  '(open/close)>5[Bashneft]',
#  '(high/low)>5[Bashneft]',
#  '(high/open)>5[Bashneft]',
#  '(low/open)>5[Bashneft]',
#  'close/close@5[Bashneft]',
#  'volume/volume@5[Bashneft]',
#  'close/close>6[Bashneft]',
#  'close>1/close>6[Bashneft]',
#  'close>2/close>6[Bashneft]',
#  'close>3/close>6[Bashneft]',
#  'close>4/close>6[Bashneft]',
#  'close>5/close>6[Bashneft]',
#  '(high/close)>6[Bashneft]',
#  '(low/close)>6[Bashneft]',
#  '(open/close)>6[Bashneft]',
#  '(high/low)>6[Bashneft]',
#  '(high/open)>6[Bashneft]',
#  '(low/open)>6[Bashneft]',
#  'close/close@6[Bashneft]',
#  'volume/volume@6[Bashneft]',
#  'close/close>9[Bashneft]',
#  'close>1/close>9[Bashneft]',
#  'close>2/close>9[Bashneft]',
#  'close>3/close>9[Bashneft]',
#  'close>4/close>9[Bashneft]',
#  'close>5/close>9[Bashneft]',
#  'close>6/close>9[Bashneft]',
#  '(high/close)>9[Bashneft]',
#  '(low/close)>9[Bashneft]',
#  '(open/close)>9[Bashneft]',
#  '(high/low)>9[Bashneft]',
#  '(high/open)>9[Bashneft]',
#  '(low/open)>9[Bashneft]',
#  'close/close@9[Bashneft]',
#  'volume/volume@9[Bashneft]',
#  'close/close>12[Bashneft]',
#  'close>1/close>12[Bashneft]',
#  'close>2/close>12[Bashneft]',
#  'close>3/close>12[Bashneft]',
#  'close>4/close>12[Bashneft]',
#  'close>5/close>12[Bashneft]',
#  'close>6/close>12[Bashneft]',
#  'close>9/close>12[Bashneft]',
#  '(high/close)>12[Bashneft]',
#  '(low/close)>12[Bashneft]',
#  '(open/close)>12[Bashneft]',
#  '(high/low)>12[Bashneft]',
#  '(high/open)>12[Bashneft]',
#  '(low/open)>12[Bashneft]',
#  'close/close@12[Bashneft]',
#  'volume/volume@12[Bashneft]',
#  'close/close>18[Bashneft]',
#  'close>1/close>18[Bashneft]',
#  'close>2/close>18[Bashneft]',
#  'close>3/close>18[Bashneft]',
#  'close>4/close>18[Bashneft]',
#  'close>5/close>18[Bashneft]',
#  'close>6/close>18[Bashneft]',
#  'close>9/close>18[Bashneft]',
#  'close>12/close>18[Bashneft]',
#  '(high/close)>18[Bashneft]',
#  '(low/close)>18[Bashneft]',
#  '(open/close)>18[Bashneft]',
#  '(high/low)>18[Bashneft]',
#  '(high/open)>18[Bashneft]',
#  '(low/open)>18[Bashneft]',
#  'close/close@18[Bashneft]',
#  'volume/volume@18[Bashneft]',
#  'close/close>24[Bashneft]',
#  'close>1/close>24[Bashneft]',
#  'close>2/close>24[Bashneft]',
#  'close>3/close>24[Bashneft]',
#  'close>4/close>24[Bashneft]',
#  'close>5/close>24[Bashneft]',
#  'close>6/close>24[Bashneft]',
#  'close>9/close>24[Bashneft]',
#  'close>12/close>24[Bashneft]',
#  'close>18/close>24[Bashneft]',
#  '(high/close)>24[Bashneft]',
#  '(low/close)>24[Bashneft]',
#  '(open/close)>24[Bashneft]',
#  '(high/low)>24[Bashneft]',
#  '(high/open)>24[Bashneft]',
#  '(low/open)>24[Bashneft]',
#  'close/close@24[Bashneft]',
#  'volume/volume@24[Bashneft]',
#  'open[Gazprom]',
#  'close[Gazprom]',
#  'high[Gazprom]',
#  'low[Gazprom]',
#  'volume[Gazprom]',
#  'high/close[Gazprom]',
#  'low/close[Gazprom]',
#  'open/close[Gazprom]',
#  'high/low[Gazprom]',
#  'high/open[Gazprom]',
#  'low/open[Gazprom]',
#  'close/close>1[Gazprom]',
#  '(high/close)>1[Gazprom]',
#  '(low/close)>1[Gazprom]',
#  '(open/close)>1[Gazprom]',
#  '(high/low)>1[Gazprom]',
#  '(high/open)>1[Gazprom]',
#  '(low/open)>1[Gazprom]',
#  'close/close@1[Gazprom]',
#  'volume/volume@1[Gazprom]',
#  'close/close>2[Gazprom]',
#  'close>1/close>2[Gazprom]',
#  '(high/close)>2[Gazprom]',
#  '(low/close)>2[Gazprom]',
#  '(open/close)>2[Gazprom]',
#  '(high/low)>2[Gazprom]',
#  '(high/open)>2[Gazprom]',
#  '(low/open)>2[Gazprom]',
#  'close/close@2[Gazprom]',
#  'volume/volume@2[Gazprom]',
#  'close/close>3[Gazprom]',
#  'close>1/close>3[Gazprom]',
#  'close>2/close>3[Gazprom]',
#  '(high/close)>3[Gazprom]',
#  '(low/close)>3[Gazprom]',
#  '(open/close)>3[Gazprom]',
#  '(high/low)>3[Gazprom]',
#  '(high/open)>3[Gazprom]',
#  '(low/open)>3[Gazprom]',
#  'close/close@3[Gazprom]',
#  'volume/volume@3[Gazprom]',
#  'close/close>4[Gazprom]',
#  'close>1/close>4[Gazprom]',
#  'close>2/close>4[Gazprom]',
#  'close>3/close>4[Gazprom]',
#  '(high/close)>4[Gazprom]',
#  '(low/close)>4[Gazprom]',
#  '(open/close)>4[Gazprom]',
#  '(high/low)>4[Gazprom]',
#  '(high/open)>4[Gazprom]',
#  '(low/open)>4[Gazprom]',
#  'close/close@4[Gazprom]',
#  'volume/volume@4[Gazprom]',
#  'close/close>5[Gazprom]',
#  'close>1/close>5[Gazprom]',
#  'close>2/close>5[Gazprom]',
#  'close>3/close>5[Gazprom]',
#  'close>4/close>5[Gazprom]',
#  '(high/close)>5[Gazprom]',
#  '(low/close)>5[Gazprom]',
#  '(open/close)>5[Gazprom]',
#  '(high/low)>5[Gazprom]',
#  '(high/open)>5[Gazprom]',
#  '(low/open)>5[Gazprom]',
#  'close/close@5[Gazprom]',
#  'volume/volume@5[Gazprom]',
#  'close/close>6[Gazprom]',
#  'close>1/close>6[Gazprom]',
#  'close>2/close>6[Gazprom]',
#  'close>3/close>6[Gazprom]',
#  'close>4/close>6[Gazprom]',
#  'close>5/close>6[Gazprom]',
#  '(high/close)>6[Gazprom]',
#  '(low/close)>6[Gazprom]',
#  '(open/close)>6[Gazprom]',
#  '(high/low)>6[Gazprom]',
#  '(high/open)>6[Gazprom]',
#  '(low/open)>6[Gazprom]',
#  'close/close@6[Gazprom]',
#  'volume/volume@6[Gazprom]',
#  'close/close>9[Gazprom]',
#  'close>1/close>9[Gazprom]',
#  'close>2/close>9[Gazprom]',
#  'close>3/close>9[Gazprom]',
#  'close>4/close>9[Gazprom]',
#  'close>5/close>9[Gazprom]',
#  'close>6/close>9[Gazprom]',
#  '(high/close)>9[Gazprom]',
#  '(low/close)>9[Gazprom]',
#  '(open/close)>9[Gazprom]',
#  '(high/low)>9[Gazprom]',
#  '(high/open)>9[Gazprom]',
#  '(low/open)>9[Gazprom]',
#  'close/close@9[Gazprom]',
#  'volume/volume@9[Gazprom]',
#  'close/close>12[Gazprom]',
#  'close>1/close>12[Gazprom]',
#  'close>2/close>12[Gazprom]',
#  'close>3/close>12[Gazprom]',
#  'close>4/close>12[Gazprom]',
#  'close>5/close>12[Gazprom]',
#  'close>6/close>12[Gazprom]',
#  'close>9/close>12[Gazprom]',
#  '(high/close)>12[Gazprom]',
#  '(low/close)>12[Gazprom]',
#  '(open/close)>12[Gazprom]',
#  '(high/low)>12[Gazprom]',
#  '(high/open)>12[Gazprom]',
#  '(low/open)>12[Gazprom]',
#  'close/close@12[Gazprom]',
#  'volume/volume@12[Gazprom]',
#  'close/close>18[Gazprom]',
#  'close>1/close>18[Gazprom]',
#  'close>2/close>18[Gazprom]',
#  'close>3/close>18[Gazprom]',
#  'close>4/close>18[Gazprom]',
#  'close>5/close>18[Gazprom]',
#  'close>6/close>18[Gazprom]',
#  'close>9/close>18[Gazprom]',
#  'close>12/close>18[Gazprom]',
#  '(high/close)>18[Gazprom]',
#  '(low/close)>18[Gazprom]',
#  '(open/close)>18[Gazprom]',
#  '(high/low)>18[Gazprom]',
#  '(high/open)>18[Gazprom]',
#  '(low/open)>18[Gazprom]',
#  'close/close@18[Gazprom]',
#  'volume/volume@18[Gazprom]',
#  'close/close>24[Gazprom]',
#  'close>1/close>24[Gazprom]',
#  'close>2/close>24[Gazprom]',
#  'close>3/close>24[Gazprom]',
#  'close>4/close>24[Gazprom]',
#  'close>5/close>24[Gazprom]',
#  'close>6/close>24[Gazprom]',
#  'close>9/close>24[Gazprom]',
#  'close>12/close>24[Gazprom]',
#  'close>18/close>24[Gazprom]',
#  '(high/close)>24[Gazprom]',
#  '(low/close)>24[Gazprom]',
#  '(open/close)>24[Gazprom]',
#  '(high/low)>24[Gazprom]',
#  '(high/open)>24[Gazprom]',
#  '(low/open)>24[Gazprom]',
#  'close/close@24[Gazprom]',
#  'volume/volume@24[Gazprom]',
#  'open[Lukoil]',
#  'close[Lukoil]',
#  'high[Lukoil]',
#  'low[Lukoil]',
#  'volume[Lukoil]',
#  'high/close[Lukoil]',
#  'low/close[Lukoil]',
#  'open/close[Lukoil]',
#  'high/low[Lukoil]',
#  'high/open[Lukoil]',
#  'low/open[Lukoil]',
#  'close/close>1[Lukoil]',
#  '(high/close)>1[Lukoil]',
#  '(low/close)>1[Lukoil]',
#  '(open/close)>1[Lukoil]',
#  '(high/low)>1[Lukoil]',
#  '(high/open)>1[Lukoil]',
#  '(low/open)>1[Lukoil]',
#  'close/close@1[Lukoil]',
#  'volume/volume@1[Lukoil]',
#  'close/close>2[Lukoil]',
#  'close>1/close>2[Lukoil]',
#  '(high/close)>2[Lukoil]',
#  '(low/close)>2[Lukoil]',
#  '(open/close)>2[Lukoil]',
#  '(high/low)>2[Lukoil]',
#  '(high/open)>2[Lukoil]',
#  '(low/open)>2[Lukoil]',
#  'close/close@2[Lukoil]',
#  'volume/volume@2[Lukoil]',
#  'close/close>3[Lukoil]',
#  'close>1/close>3[Lukoil]',
#  'close>2/close>3[Lukoil]',
#  '(high/close)>3[Lukoil]',
#  '(low/close)>3[Lukoil]',
#  '(open/close)>3[Lukoil]',
#  '(high/low)>3[Lukoil]',
#  '(high/open)>3[Lukoil]',
#  '(low/open)>3[Lukoil]',
#  'close/close@3[Lukoil]',
#  'volume/volume@3[Lukoil]',
#  'close/close>4[Lukoil]',
#  'close>1/close>4[Lukoil]',
#  'close>2/close>4[Lukoil]',
#  'close>3/close>4[Lukoil]',
#  '(high/close)>4[Lukoil]',
#  '(low/close)>4[Lukoil]',
#  '(open/close)>4[Lukoil]',
#  '(high/low)>4[Lukoil]',
#  '(high/open)>4[Lukoil]',
#  '(low/open)>4[Lukoil]',
#  'close/close@4[Lukoil]',
#  'volume/volume@4[Lukoil]',
#  'close/close>5[Lukoil]',
#  'close>1/close>5[Lukoil]',
#  'close>2/close>5[Lukoil]',
#  'close>3/close>5[Lukoil]',
#  'close>4/close>5[Lukoil]',
#  '(high/close)>5[Lukoil]',
#  '(low/close)>5[Lukoil]',
#  '(open/close)>5[Lukoil]',
#  '(high/low)>5[Lukoil]',
#  '(high/open)>5[Lukoil]',
#  '(low/open)>5[Lukoil]',
#  'close/close@5[Lukoil]',
#  'volume/volume@5[Lukoil]',
#  'close/close>6[Lukoil]',
#  'close>1/close>6[Lukoil]',
#  'close>2/close>6[Lukoil]',
#  'close>3/close>6[Lukoil]',
#  'close>4/close>6[Lukoil]',
#  'close>5/close>6[Lukoil]',
#  '(high/close)>6[Lukoil]',
#  '(low/close)>6[Lukoil]',
#  '(open/close)>6[Lukoil]',
#  '(high/low)>6[Lukoil]',
#  '(high/open)>6[Lukoil]',
#  '(low/open)>6[Lukoil]',
#  'close/close@6[Lukoil]',
#  'volume/volume@6[Lukoil]',
#  'close/close>9[Lukoil]',
#  'close>1/close>9[Lukoil]',
#  'close>2/close>9[Lukoil]',
#  'close>3/close>9[Lukoil]',
#  'close>4/close>9[Lukoil]',
#  'close>5/close>9[Lukoil]',
#  'close>6/close>9[Lukoil]',
#  '(high/close)>9[Lukoil]',
#  '(low/close)>9[Lukoil]',
#  '(open/close)>9[Lukoil]',
#  '(high/low)>9[Lukoil]',
#  '(high/open)>9[Lukoil]',
#  '(low/open)>9[Lukoil]',
#  'close/close@9[Lukoil]',
#  'volume/volume@9[Lukoil]',
#  'close/close>12[Lukoil]',
#  'close>1/close>12[Lukoil]',
#  'close>2/close>12[Lukoil]',
#  'close>3/close>12[Lukoil]',
#  'close>4/close>12[Lukoil]',
#  'close>5/close>12[Lukoil]',
#  'close>6/close>12[Lukoil]',
#  'close>9/close>12[Lukoil]',
#  '(high/close)>12[Lukoil]',
#  '(low/close)>12[Lukoil]',
#  '(open/close)>12[Lukoil]',
#  '(high/low)>12[Lukoil]',
#  '(high/open)>12[Lukoil]',
#  '(low/open)>12[Lukoil]',
#  'close/close@12[Lukoil]',
#  'volume/volume@12[Lukoil]',
#  'close/close>18[Lukoil]',
#  'close>1/close>18[Lukoil]',
#  'close>2/close>18[Lukoil]',
#  'close>3/close>18[Lukoil]',
#  'close>4/close>18[Lukoil]',
#  'close>5/close>18[Lukoil]',
#  'close>6/close>18[Lukoil]',
#  'close>9/close>18[Lukoil]',
#  'close>12/close>18[Lukoil]',
#  '(high/close)>18[Lukoil]',
#  '(low/close)>18[Lukoil]',
#  '(open/close)>18[Lukoil]',
#  '(high/low)>18[Lukoil]',
#  '(high/open)>18[Lukoil]',
#  '(low/open)>18[Lukoil]',
#  'close/close@18[Lukoil]',
#  'volume/volume@18[Lukoil]',
#  'close/close>24[Lukoil]',
#  'close>1/close>24[Lukoil]',
#  'close>2/close>24[Lukoil]',
#  'close>3/close>24[Lukoil]',
#  'close>4/close>24[Lukoil]',
#  'close>5/close>24[Lukoil]',
#  'close>6/close>24[Lukoil]',
#  'close>9/close>24[Lukoil]',
#  'close>12/close>24[Lukoil]',
#  'close>18/close>24[Lukoil]',
#  '(high/close)>24[Lukoil]',
#  '(low/close)>24[Lukoil]',
#  '(open/close)>24[Lukoil]',
#  '(high/low)>24[Lukoil]',
#  '(high/open)>24[Lukoil]',
#  '(low/open)>24[Lukoil]',
#  'close/close@24[Lukoil]',
#  'volume/volume@24[Lukoil]',
#  'open[Novatek]',
#  'close[Novatek]',
#  'high[Novatek]',
#  'low[Novatek]',
#  'volume[Novatek]',
#  'high/close[Novatek]',
#  'low/close[Novatek]',
#  'open/close[Novatek]',
#  'high/low[Novatek]',
#  'high/open[Novatek]',
#  'low/open[Novatek]',
#  'close/close>1[Novatek]',
#  '(high/close)>1[Novatek]',
#  '(low/close)>1[Novatek]',
#  '(open/close)>1[Novatek]',
#  '(high/low)>1[Novatek]',
#  '(high/open)>1[Novatek]',
#  '(low/open)>1[Novatek]',
#  'close/close@1[Novatek]',
#  'volume/volume@1[Novatek]',
#  'close/close>2[Novatek]',
#  'close>1/close>2[Novatek]',
#  '(high/close)>2[Novatek]',
#  '(low/close)>2[Novatek]',
#  '(open/close)>2[Novatek]',
#  '(high/low)>2[Novatek]',
#  '(high/open)>2[Novatek]',
#  '(low/open)>2[Novatek]',
#  'close/close@2[Novatek]',
#  'volume/volume@2[Novatek]',
#  'close/close>3[Novatek]',
#  'close>1/close>3[Novatek]',
#  'close>2/close>3[Novatek]',
#  '(high/close)>3[Novatek]',
#  '(low/close)>3[Novatek]',
#  '(open/close)>3[Novatek]',
#  '(high/low)>3[Novatek]',
#  '(high/open)>3[Novatek]',
#  '(low/open)>3[Novatek]',
#  'close/close@3[Novatek]',
#  'volume/volume@3[Novatek]',
#  'close/close>4[Novatek]',
#  'close>1/close>4[Novatek]',
#  'close>2/close>4[Novatek]',
#  'close>3/close>4[Novatek]',
#  '(high/close)>4[Novatek]',
#  '(low/close)>4[Novatek]',
#  '(open/close)>4[Novatek]',
#  '(high/low)>4[Novatek]',
#  '(high/open)>4[Novatek]',
#  '(low/open)>4[Novatek]',
#  'close/close@4[Novatek]',
#  'volume/volume@4[Novatek]',
#  'close/close>5[Novatek]',
#  'close>1/close>5[Novatek]',
#  'close>2/close>5[Novatek]',
#  'close>3/close>5[Novatek]',
#  'close>4/close>5[Novatek]',
#  '(high/close)>5[Novatek]',
#  '(low/close)>5[Novatek]',
#  '(open/close)>5[Novatek]',
#  '(high/low)>5[Novatek]',
#  '(high/open)>5[Novatek]',
#  '(low/open)>5[Novatek]',
#  'close/close@5[Novatek]',
#  'volume/volume@5[Novatek]',
#  'close/close>6[Novatek]',
#  'close>1/close>6[Novatek]',
#  'close>2/close>6[Novatek]',
#  'close>3/close>6[Novatek]',
#  'close>4/close>6[Novatek]',
#  'close>5/close>6[Novatek]',
#  '(high/close)>6[Novatek]',
#  '(low/close)>6[Novatek]',
#  '(open/close)>6[Novatek]',
#  '(high/low)>6[Novatek]',
#  '(high/open)>6[Novatek]',
#  '(low/open)>6[Novatek]',
#  'close/close@6[Novatek]',
#  'volume/volume@6[Novatek]',
#  'close/close>9[Novatek]',
#  'close>1/close>9[Novatek]',
#  'close>2/close>9[Novatek]',
#  'close>3/close>9[Novatek]',
#  'close>4/close>9[Novatek]',
#  'close>5/close>9[Novatek]',
#  'close>6/close>9[Novatek]',
#  '(high/close)>9[Novatek]',
#  '(low/close)>9[Novatek]',
#  '(open/close)>9[Novatek]',
#  '(high/low)>9[Novatek]',
#  '(high/open)>9[Novatek]',
#  '(low/open)>9[Novatek]',
#  'close/close@9[Novatek]',
#  'volume/volume@9[Novatek]',
#  'close/close>12[Novatek]',
#  'close>1/close>12[Novatek]',
#  'close>2/close>12[Novatek]',
#  'close>3/close>12[Novatek]',
#  'close>4/close>12[Novatek]',
#  'close>5/close>12[Novatek]',
#  'close>6/close>12[Novatek]',
#  'close>9/close>12[Novatek]',
#  '(high/close)>12[Novatek]',
#  '(low/close)>12[Novatek]',
#  '(open/close)>12[Novatek]',
#  '(high/low)>12[Novatek]',
#  '(high/open)>12[Novatek]',
#  '(low/open)>12[Novatek]',
#  'close/close@12[Novatek]',
#  'volume/volume@12[Novatek]',
#  'close/close>18[Novatek]',
#  'close>1/close>18[Novatek]',
#  'close>2/close>18[Novatek]',
#  'close>3/close>18[Novatek]',
#  'close>4/close>18[Novatek]',
#  'close>5/close>18[Novatek]',
#  'close>6/close>18[Novatek]',
#  'close>9/close>18[Novatek]',
#  'close>12/close>18[Novatek]',
#  '(high/close)>18[Novatek]',
#  '(low/close)>18[Novatek]',
#  '(open/close)>18[Novatek]',
#  '(high/low)>18[Novatek]',
#  '(high/open)>18[Novatek]',
#  '(low/open)>18[Novatek]',
#  'close/close@18[Novatek]',
#  'volume/volume@18[Novatek]',
#  'close/close>24[Novatek]',
#  'close>1/close>24[Novatek]',
#  'close>2/close>24[Novatek]',
#  'close>3/close>24[Novatek]',
#  'close>4/close>24[Novatek]',
#  'close>5/close>24[Novatek]',
#  'close>6/close>24[Novatek]',
#  'close>9/close>24[Novatek]',
#  'close>12/close>24[Novatek]',
#  'close>18/close>24[Novatek]',
#  '(high/close)>24[Novatek]',
#  '(low/close)>24[Novatek]',
#  '(open/close)>24[Novatek]',
#  '(high/low)>24[Novatek]',
#  '(high/open)>24[Novatek]',
#  '(low/open)>24[Novatek]',
#  'close/close@24[Novatek]',
#  'volume/volume@24[Novatek]',
#  'open[Rosneft]',
#  'close[Rosneft]',
#  'high[Rosneft]',
#  'low[Rosneft]',
#  'volume[Rosneft]',
#  'high/close[Rosneft]',
#  'low/close[Rosneft]',
#  'open/close[Rosneft]',
#  'high/low[Rosneft]',
#  'high/open[Rosneft]',
#  'low/open[Rosneft]',
#  'close/close>1[Rosneft]',
#  '(high/close)>1[Rosneft]',
#  '(low/close)>1[Rosneft]',
#  '(open/close)>1[Rosneft]',
#  '(high/low)>1[Rosneft]',
#  '(high/open)>1[Rosneft]',
#  '(low/open)>1[Rosneft]',
#  'close/close@1[Rosneft]',
#  'volume/volume@1[Rosneft]',
#  'close/close>2[Rosneft]',
#  'close>1/close>2[Rosneft]',
#  '(high/close)>2[Rosneft]',
#  '(low/close)>2[Rosneft]',
#  '(open/close)>2[Rosneft]',
#  '(high/low)>2[Rosneft]',
#  '(high/open)>2[Rosneft]',
#  '(low/open)>2[Rosneft]',
#  'close/close@2[Rosneft]',
#  'volume/volume@2[Rosneft]',
#  'close/close>3[Rosneft]',
#  'close>1/close>3[Rosneft]',
#  'close>2/close>3[Rosneft]',
#  '(high/close)>3[Rosneft]',
#  '(low/close)>3[Rosneft]',
#  '(open/close)>3[Rosneft]',
#  '(high/low)>3[Rosneft]',
#  '(high/open)>3[Rosneft]',
#  '(low/open)>3[Rosneft]',
#  'close/close@3[Rosneft]',
#  'volume/volume@3[Rosneft]',
#  'close/close>4[Rosneft]',
#  'close>1/close>4[Rosneft]',
#  'close>2/close>4[Rosneft]',
#  'close>3/close>4[Rosneft]',
#  '(high/close)>4[Rosneft]',
#  '(low/close)>4[Rosneft]',
#  '(open/close)>4[Rosneft]',
#  '(high/low)>4[Rosneft]',
#  '(high/open)>4[Rosneft]',
#  '(low/open)>4[Rosneft]',
#  'close/close@4[Rosneft]',
#  'volume/volume@4[Rosneft]',
#  'close/close>5[Rosneft]',
#  'close>1/close>5[Rosneft]',
#  'close>2/close>5[Rosneft]',
#  'close>3/close>5[Rosneft]',
#  'close>4/close>5[Rosneft]',
#  '(high/close)>5[Rosneft]',
#  '(low/close)>5[Rosneft]',
#  '(open/close)>5[Rosneft]',
#  '(high/low)>5[Rosneft]',
#  '(high/open)>5[Rosneft]',
#  '(low/open)>5[Rosneft]',
#  'close/close@5[Rosneft]',
#  'volume/volume@5[Rosneft]',
#  'close/close>6[Rosneft]',
#  'close>1/close>6[Rosneft]',
#  'close>2/close>6[Rosneft]',
#  'close>3/close>6[Rosneft]',
#  'close>4/close>6[Rosneft]',
#  'close>5/close>6[Rosneft]',
#  '(high/close)>6[Rosneft]',
#  '(low/close)>6[Rosneft]',
#  '(open/close)>6[Rosneft]',
#  '(high/low)>6[Rosneft]',
#  '(high/open)>6[Rosneft]',
#  '(low/open)>6[Rosneft]',
#  'close/close@6[Rosneft]',
#  'volume/volume@6[Rosneft]',
#  'close/close>9[Rosneft]',
#  'close>1/close>9[Rosneft]',
#  'close>2/close>9[Rosneft]',
#  'close>3/close>9[Rosneft]',
#  'close>4/close>9[Rosneft]',
#  'close>5/close>9[Rosneft]',
#  'close>6/close>9[Rosneft]',
#  '(high/close)>9[Rosneft]',
#  '(low/close)>9[Rosneft]',
#  '(open/close)>9[Rosneft]',
#  '(high/low)>9[Rosneft]',
#  '(high/open)>9[Rosneft]',
#  '(low/open)>9[Rosneft]',
#  'close/close@9[Rosneft]',
#  'volume/volume@9[Rosneft]',
#  'close/close>12[Rosneft]',
#  'close>1/close>12[Rosneft]',
#  'close>2/close>12[Rosneft]',
#  'close>3/close>12[Rosneft]',
#  'close>4/close>12[Rosneft]',
#  'close>5/close>12[Rosneft]',
#  'close>6/close>12[Rosneft]',
#  'close>9/close>12[Rosneft]',
#  '(high/close)>12[Rosneft]',
#  '(low/close)>12[Rosneft]',
#  '(open/close)>12[Rosneft]',
#  '(high/low)>12[Rosneft]',
#  '(high/open)>12[Rosneft]',
#  '(low/open)>12[Rosneft]',
#  'close/close@12[Rosneft]',
#  'volume/volume@12[Rosneft]',
#  'close/close>18[Rosneft]',
#  'close>1/close>18[Rosneft]',
#  'close>2/close>18[Rosneft]',
#  'close>3/close>18[Rosneft]',
#  'close>4/close>18[Rosneft]',
#  'close>5/close>18[Rosneft]',
#  'close>6/close>18[Rosneft]',
#  'close>9/close>18[Rosneft]',
#  'close>12/close>18[Rosneft]',
#  '(high/close)>18[Rosneft]',
#  '(low/close)>18[Rosneft]',
#  '(open/close)>18[Rosneft]',
#  '(high/low)>18[Rosneft]',
#  '(high/open)>18[Rosneft]',
#  '(low/open)>18[Rosneft]',
#  'close/close@18[Rosneft]',
#  'volume/volume@18[Rosneft]',
#  'close/close>24[Rosneft]',
#  'close>1/close>24[Rosneft]',
#  'close>2/close>24[Rosneft]',
#  'close>3/close>24[Rosneft]',
#  'close>4/close>24[Rosneft]',
#  'close>5/close>24[Rosneft]',
#  'close>6/close>24[Rosneft]',
#  'close>9/close>24[Rosneft]',
#  'close>12/close>24[Rosneft]',
#  'close>18/close>24[Rosneft]',
#  '(high/close)>24[Rosneft]',
#  '(low/close)>24[Rosneft]',
#  '(open/close)>24[Rosneft]',
#  '(high/low)>24[Rosneft]',
#  '(high/open)>24[Rosneft]',
#  '(low/open)>24[Rosneft]',
#  'close/close@24[Rosneft]',
#  'volume/volume@24[Rosneft]',
#  'close/close>1[Bashneft]-close/close>1[Tatneft]',
#  'high/low[Bashneft]-high/low[Tatneft]',
#  'high/close[Bashneft]-high/close[Tatneft]',
#  'close/close>1[Bashneft]-close/close>1[Gazprom]',
#  'high/low[Bashneft]-high/low[Gazprom]',
#  'high/close[Bashneft]-high/close[Gazprom]',
#  'close/close>1[Bashneft]-close/close>1[Lukoil]',
#  'high/low[Bashneft]-high/low[Lukoil]',
#  'high/close[Bashneft]-high/close[Lukoil]',
#  'close/close>1[Bashneft]-close/close>1[Novatek]',
#  'high/low[Bashneft]-high/low[Novatek]',
#  'high/close[Bashneft]-high/close[Novatek]',
#  'close/close>1[Bashneft]-close/close>1[Rosneft]',
#  'high/low[Bashneft]-high/low[Rosneft]',
#  'high/close[Bashneft]-high/close[Rosneft]',
#  'close/close>1[Gazprom]-close/close>1[Tatneft]',
#  'high/low[Gazprom]-high/low[Tatneft]',
#  'high/close[Gazprom]-high/close[Tatneft]',
#  'close/close>1[Gazprom]-close/close>1[Lukoil]',
#  'high/low[Gazprom]-high/low[Lukoil]',
#  'high/close[Gazprom]-high/close[Lukoil]',
#  'close/close>1[Gazprom]-close/close>1[Novatek]',
#  'high/low[Gazprom]-high/low[Novatek]',
#  'high/close[Gazprom]-high/close[Novatek]',
#  'close/close>1[Gazprom]-close/close>1[Rosneft]',
#  'high/low[Gazprom]-high/low[Rosneft]',
#  'high/close[Gazprom]-high/close[Rosneft]',
#  'close/close>1[Lukoil]-close/close>1[Tatneft]',
#  'high/low[Lukoil]-high/low[Tatneft]',
#  'high/close[Lukoil]-high/close[Tatneft]',
#  'close/close>1[Lukoil]-close/close>1[Novatek]',
#  'high/low[Lukoil]-high/low[Novatek]',
#  'high/close[Lukoil]-high/close[Novatek]',
#  'close/close>1[Lukoil]-close/close>1[Rosneft]',
#  'high/low[Lukoil]-high/low[Rosneft]',
#  'high/close[Lukoil]-high/close[Rosneft]',
#  'close/close>1[Novatek]-close/close>1[Tatneft]',
#  'high/low[Novatek]-high/low[Tatneft]',
#  'high/close[Novatek]-high/close[Tatneft]',
#  'close/close>1[Novatek]-close/close>1[Rosneft]',
#  'high/low[Novatek]-high/low[Rosneft]',
#  'high/close[Novatek]-high/close[Rosneft]',
#  'close/close>1[Rosneft]-close/close>1[Tatneft]',
#  'high/low[Rosneft]-high/low[Tatneft]',
#  'high/close[Rosneft]-high/close[Tatneft]']
